# %%
import numpy as np
import csv
from numpy import *
import os


def get_tf_list(tf_path):
    # return tf_list
    f_tf = open(tf_path)
    tf_reader = list(csv.reader(f_tf))
    tf_list = []
    for single in tf_reader[1:]:
        tf_list.append(single[0])
    print('Load ' + str(len(tf_list)) + ' TFs successfully!')
    return tf_list

def get_origin_expression_data(gene_expression_path):
    # return 1.tf-targets dict and pair-score dict
    #        2.number of timepoints
    f_expression = open(gene_expression_path, encoding="utf-8")
    expression_reader = list(csv.reader(f_expression))
    cells = expression_reader[0][1:]
    num_cells = len(cells)

    expression_record = {}
    num_genes = 0
    for single_expression_reader in expression_reader[1:]:
        if single_expression_reader[0] in expression_record:
            print('Gene name ' + single_expression_reader[0] + ' repeat!')
        expression_record[single_expression_reader[0]] = list(map(float, single_expression_reader[1:]))
        num_genes += 1
    print(str(num_genes) + ' genes and ' + str(num_cells) + ' cells are included in origin expression data.')
    return expression_record, cells

def get_normalized_expression_data(gene_expression_path):
    # return 1.tf-targets dict and pair-score dict
    #        2.number of timepoints
    expression_record, cells = get_origin_expression_data(gene_expression_path)
    expression_matrix = np.zeros((len(expression_record), len(cells)))
    index_row = 0
    for gene in expression_record:
        expression_record[gene] = np.log10(np.array(expression_record[gene]) + 10 ** -2)
        expression_matrix[index_row] = expression_record[gene]
        index_row += 1

    # Heat map
    # plt.figure(figsize=(15,15))
    # sns.heatmap(expression_matrix[0:100,0:100])
    # plt.show()

    return expression_record, cells

def get_gene_ranking(gene_order_path, low_express_gene_list, gene_num, output_path,
                     flag):  # flag=True:write to output_path
    # 1.delete genes p-value>=0.01
    # 2.delete genes with low expression
    # 3.rank genes in descending order of variance
    # 4.return gene names list of top genes and variance_record of p-value<0.01
    f_order = open(gene_order_path)
    order_reader = list(csv.reader(f_order))
    if flag:
        f_rank = open(output_path, 'w', newline='\n')
        f_rank_writer = csv.writer(f_rank)
    variance_record = {}
    variance_list = []
    significant_gene_list = []
    for single_order_reader in order_reader[1:]:
        # column 0:gene name
        # column 1:p value
        # column 2:variance
        if float(single_order_reader[1]) >= 0.01:
            break
        if single_order_reader[0] in low_express_gene_list:
            continue
        variance = float(single_order_reader[2])
        if variance not in variance_record:  # 1 variance corresponding to 1 gene
            variance_record[variance] = single_order_reader[0]
        else:  # 1 variance corresponding to n genes
            print(str(variance_record[variance]) + ' and ' + single_order_reader[0] + ' variance repeat!')
            variance_record[variance] = [variance_record[variance]]
            variance_record[variance].append(single_order_reader[0])
        variance_list.append(variance)
        tstr = single_order_reader[0]
        single_order_reader[0] = tstr.upper()
        significant_gene_list.append(single_order_reader[0])
    print('After delete genes with p-value>=0.01 or low expression, ' + str(len(variance_list)) + ' genes left.')
    variance_list.sort(reverse=True)
    gene_rank = []
    for single_variance_list in variance_list[0:gene_num]:
        if type(variance_record[single_variance_list]) is str:  # 1 variance corresponding to 1 gene
            gene_rank.append(variance_record[single_variance_list])
        else:  # 1 variance corresponding to n genes
            gene_rank.append(variance_record[single_variance_list][0])
            del variance_record[single_variance_list][0]
            if len(variance_record[single_variance_list]) == 1:
                variance_record[single_variance_list] = variance_record[single_variance_list][0]
        if flag:
            f_rank_writer.writerow([variance_record[single_variance_list]])
    f_order.close()
    if flag:
        f_rank.close()
    return gene_rank, significant_gene_list

def get_filtered_gold(gold_network_path, rank_list, output_path, flag):
    # 1.Load origin gold file
    # 2.Delete genes not in rank_list
    # 3.return tf-targets dict and pair-score dict
    # Note: If no score in gold network, score=999
    f_gold = open(gold_network_path, encoding='UTF-8-sig')
    gold_reader = list(csv.reader(f_gold))
    for i in range(0, len(gold_reader) - 1):
        temp = gold_reader[i]
        s1 = str(temp[0])
        s2 = str(temp[1])

        temp[0] = s1.upper()
        temp[1] = s2.upper()

        gold_reader[i] = temp
    # print("gold_reader",gold_reader)
    # print("rank_list",rank_list)
    # print("gold_reader",gold_reader)
    print("gold_reader[0]", gold_reader[0])
    has_score = True
    if len(gold_reader[0]) < 3:
        has_score = False
    gold_pair_record = {}
    gold_score_record = {}
    unique_gene_list = []
    for single_gold_reader in gold_reader[1:]:
        # column 0: TF
        # column 1: target gene
        # column 2: regulate score
        if (single_gold_reader[0] not in rank_list) or (single_gold_reader[1] not in rank_list):
            continue
        gene_pair = [single_gold_reader[0], single_gold_reader[1]]
        str_gene_pair = single_gold_reader[0] + ',' + single_gold_reader[1]

        if single_gold_reader[0] not in unique_gene_list: unique_gene_list.append(single_gold_reader[0])
        if single_gold_reader[1] not in unique_gene_list: unique_gene_list.append(single_gold_reader[1])
        if str_gene_pair in gold_score_record:
            print('Gold pair repeat!')
        if has_score:
            print("single_gold_reader[2]", single_gold_reader[2])
            gold_score_record[str_gene_pair] = float(single_gold_reader[2])
        else:
            gold_score_record[str_gene_pair] = 999
        if gene_pair[0] not in gold_pair_record:
            gold_pair_record[gene_pair[0]] = [gene_pair[1]]
        else:
            gold_pair_record[gene_pair[0]].append(gene_pair[1])
    print("gold_pair_record", gold_pair_record)
    # Some statistics of gold_network
    print(str(len(gold_pair_record)) + ' TFs and ' + str(
        len(gold_score_record)) + ' edges in gold_network consisted of genes in rank_list.')
    print(str(len(unique_gene_list)) + ' genes are common in rank_list and gold_network.')

    rank_density = len(gold_score_record) / (len(gold_pair_record) * (len(rank_list)))
    gold_density = len(gold_score_record) / (len(gold_pair_record) * (len(unique_gene_list)))

    print('Rank genes density = edges/(TFs*(len(rank_gene)-1))=' + str(rank_density))
    print('Gold genes density = edges/(TFs*len(unique_gene_list))=' + str(gold_density))

    # write to file
    print("unique_gene_list", unique_gene_list)
    if flag:
        f_unique = open(output_path, 'w', encoding="utf-8", newline='\n')
        f_unique_writer = csv.writer(f_unique)
        out_unique = np.array(unique_gene_list).reshape(len(unique_gene_list), 1)
        f_unique_writer.writerows(out_unique)
        f_unique.close()
    return gold_pair_record, gold_score_record, unique_gene_list

def generate_filtered_gold(gold_pair_record, gold_score_record, output_path):
    # write filtered_gold to output_path
    # print("cnm")
    f_filtered = open(output_path, 'w', encoding="utf-8", newline='\n')
    f_filtered_writer = csv.writer(f_filtered)
    f_filtered_writer.writerow(['TF', 'Target', 'Score'])
    # print("cnm")
    for tf in gold_pair_record:
        once_output = []
        for target in gold_pair_record[tf]:
            single_output = [tf, target, gold_score_record[tf + ',' + target]]
            once_output.append(single_output)
        f_filtered_writer.writerows(once_output)
    f_filtered.close()

def get_gene_pair_list(unique_gene_list, gold_pair_record, gold_score_record, output_file):
    # positive is relationship that tf regulate target
    # negtive is reationship that same tf doesn's regulate target.
    # When same tf doesn't have enough negtive, borrow negtive from other TFs.
    # When negtive is not enough,stop and prove positive:negtive = 1:1

    # generate all negtive gene pairs of TFs
    all_tf_negtive_record = {}
    for tf in gold_pair_record:
        # print("tf",tf)
        all_tf_negtive_record[tf] = []
        for target in unique_gene_list:
            if target in gold_pair_record[tf]:
                continue
            all_tf_negtive_record[tf].append(target)

    # generate negtive record without borrow
    rank_negtive_record = {}
    for tf in gold_pair_record:
        num_positive = len(gold_pair_record[tf])
        if num_positive > len(all_tf_negtive_record[tf]):
            rank_negtive_record[tf] = all_tf_negtive_record[tf]
            all_tf_negtive_record[tf] = []
        else:
            # maybe random.sample(all_tf_negtive_record[tf],num_positive) to promote performance
            rank_negtive_record[tf] = all_tf_negtive_record[tf][:num_positive]
            all_tf_negtive_record[tf] = all_tf_negtive_record[tf][num_positive:]

    # output positive and negtive pairs
    f_gpl = open(output_file, 'w', newline='\n')
    f_gpl_writer = csv.writer(f_gpl)
    f_gpl_writer.writerow(['TF', 'Target', 'Label', 'Score'])
    stop_flag = False
    for tf in gold_pair_record:
        once_output = []
        for target in gold_pair_record[tf]:
            # output positive
            single_output = [tf, target, '1', gold_score_record[tf + ',' + target]]
            once_output.append(single_output)
            # output negtive
            if len(rank_negtive_record[tf]) == 0:
                # borrow negtive for other TFs
                find_negtive = False
                for borrow_tf in all_tf_negtive_record:
                    if len(all_tf_negtive_record[borrow_tf]) > 0:
                        find_negtive = True
                        single_output = [borrow_tf, all_tf_negtive_record[borrow_tf][0], 0, 0]
                        del all_tf_negtive_record[borrow_tf][0]
                        break
                # if not enough negtive of others,stop and prove positive:negtive = 1:1
                if not find_negtive:
                    stop_flag = True
                    break
            else:
                # negtive without borrow
                single_output = [tf, rank_negtive_record[tf][0], 0, 0]
                del rank_negtive_record[tf][0]
            once_output.append(single_output)
        if stop_flag:
            f_gpl_writer.writerows(once_output[:-1])
            print('Negtive not enough!')
            break
        f_gpl_writer.writerows(once_output)  # output positive and negtive of 1 TF at a time
    f_gpl.close()

def get_low_express_gene(origin_expression_record, num_cells):
    # get gene_list who were expressed in fewer than 10% of the cells
    gene_list = []
    threshold = num_cells // 10
    for gene in origin_expression_record:
        num = 0
        for expression in origin_expression_record[gene]:
            if expression != 0:
                num += 1
                if num > threshold:
                    break
        if num <= threshold:
            gene_list.append(gene)
    return gene_list


def loadData(network, dataset):

    gene_pair_list_path = "exampleData/" + network
    gene_expression_path = "exampleData/" + dataset
    resultPath = "exampleData/input/"
    origin_expression_record, cells = get_normalized_expression_data(gene_expression_path)
    print("len(origin_expression_record)", len(origin_expression_record))

    # Load gold_pair_record
    all_gene_list = []
    gold_pair_record = {}
    f_genePairList = open(gene_pair_list_path, encoding='UTF-8')  ### read the gene pair and label file

    for single_pair in list(csv.reader(f_genePairList))[1:]:
        print("single_pair",single_pair)
        if single_pair[2] == '1':
            if single_pair[0] not in gold_pair_record:
                gold_pair_record[single_pair[0]] = [single_pair[1]]
            else:
                gold_pair_record[single_pair[0]].append(single_pair[1])
            # count all genes in gold edges
            if single_pair[0] not in all_gene_list:
                all_gene_list.append(single_pair[0])
            if single_pair[1] not in all_gene_list:
                all_gene_list.append(single_pair[1])
    f_genePairList.close()
    # print dataset statistics
    print('All genes:' + str(len(all_gene_list)))
    print('TFs:' + str(len(gold_pair_record.keys())))
    print("len(single_pair)", len(single_pair))
    # Generate Pearson matrix
    label_list = []
    pair_list = []
    total_matrix = []
    num_tf = -1
    num_label1 = 0
    num_label0 = 0

    # control cell numbers by means of timepoints
    timepoints = len(cells)
    # timepoints=800
    x = []
    for i in gold_pair_record:
        num_tf += 1
        for j in range(len(all_gene_list)):
            # for j in range(2):
            print('Generating matrix of gene pair ' + str(num_tf) + ' ' + str(j))
            tf_name = i
            target_name = all_gene_list[j]

            flag = False
            if (origin_expression_record.__contains__(tf_name) & origin_expression_record.__contains__(target_name)):
                flag = True

            if (flag):
                if tf_name in gold_pair_record and target_name in gold_pair_record[tf_name]:
                    label = 1
                    num_label1 += 1
                else:
                    label = 0
                    num_label0 += 1
                label_list.append(label)
                pair_list.append(tf_name + ',' + target_name)

                tf_data = origin_expression_record[tf_name]
                target_data = origin_expression_record[target_name]
            else:
                miss = miss + 1
                continue

            single_tf_list = []
            gap = 100
            for k in range(0, len(tf_data), gap):
                feature = []
                a = tf_data[k:k + gap]
                b = target_data[k:k + gap]
                feature.extend(a)
                feature.extend(b)
                # single_tf_list.append(feature)
                feature = np.asarray(feature)
                # print("feature.shape", feature.shape)
                if (len(feature) == 2 * gap):
                    # print("feature.shape xixihaha", feature.shape)
                    single_tf_list.append(feature)

            single_tf_list = np.asarray(single_tf_list)

            total_matrix.append(single_tf_list)

    total_matrix = np.asarray(total_matrix)
    label_list = np.array(label_list)
    # print("label_list.shape", label_list.shape)
    pair_list = np.array(pair_list)

    np.save(resultPath + 'matrix.npy', total_matrix)
    np.save(resultPath + 'label.npy', label_list)
    np.save(resultPath + 'gene_pair.npy', pair_list)

    print('PCC matrix generation finish.')
    print('Positive edges:' + str(num_label1))
    print('Negative edges:' + str(num_label0))
    print('Density=' + str(num_label1 / (num_label1 + num_label0)))

known_network = "known_network.csv"

unknown_network = "unknown_network.csv"
dataset = "06hHep_ExpressionDataOrdered.csv"

##generating the data can be inputted by the STGRNS
loadData(known_network, dataset)
loadData(unknown_network, dataset)
# Out:
# Gene name 1-Mar repeat!
# 11515 genes and 425 cells are included in origin expression data.
# len(origin_expression_record) 11514
# single_pair ['KLF6', 'CRABP2', '0']
# single_pair ['ID2', 'SCHIP1', '0']
# single_pair ['FOS', 'DPCD', '1']
# single_pair ['ZNF143', 'APEH', '0']
# single_pair ['PTTG1', 'NIP7', '0']
# single_pair ['ZNF143', 'MRPS27', '0']
# single_pair ['NFYB', 'MCM3', '0']
# single_pair ['NFYB', 'DPYSL2', '1']
# single_pair ['KLF6', 'MT2A', '0']
# single_pair ['OTX2', 'RUVBL1', '0']
# single_pair ['MCM3', 'ZNF143', '0']
# single_pair ['PTTG1', 'ZWILCH', '0']
# single_pair ['MCM4', 'MCM3', '1']
# single_pair ['MCM3', 'SERPINB1', '0']
# single_pair ['FOS', 'CCBL2', '1']
# single_pair ['CRABP2', 'GRPR', '0']
# single_pair ['ZNF143', 'ATG5', '0']
# single_pair ['KLF6', 'SMYD3', '0']
# single_pair ['KLF6', 'DPYSL2', '0']
# single_pair ['NFYB', 'MTFP1', '0']
# single_pair ['MCM3', 'BUB1B', '0']
# single_pair ['OTX2', 'TNFRSF12A', '0']
# single_pair ['ZNF143', 'KNTC1', '0']
# single_pair ['NFYB', 'DPCD', '0']
# single_pair ['FOS', 'F3', '1']
# single_pair ['OTX2', 'PCCA', '0']
# single_pair ['TGIF1', 'CYP3A5', '0']
# single_pair ['RUVBL1', 'PTTG1', '0']
# single_pair ['ID2', 'ACADVL', '0']
# single_pair ['KNTC1', 'ICA1', '0']
# single_pair ['DDIT3', 'TF', '1']
# single_pair ['MCM7', 'AURKA', '0']
# single_pair ['ID2', 'ZWILCH', '0']
# single_pair ['ZNF143', 'CAPN12', '0']
# single_pair ['RUVBL1', 'CAMK2D', '0']
# single_pair ['DDIT3', 'ACTC1', '0']
# single_pair ['NFYB', 'LGALS1', '0']
# single_pair ['MCM3', 'CCNH', '0']
# single_pair ['KNTC1', 'SCHIP1', '0']
# single_pair ['FOS', 'GPC3', '0']
# single_pair ['CRABP2', 'CAPN12', '0']
# single_pair ['CRABP2', 'NQO1', '0']
# single_pair ['KNTC1', 'PMAIP1', '0']
# single_pair ['ZNF143', 'MCM4', '0']
# single_pair ['OTX2', 'PMAIP1', '0']
# single_pair ['KLF6', 'PIM2', '0']
# single_pair ['KNTC1', 'KNTC1', '0']
# single_pair ['KNTC1', 'F3', '0']
# single_pair ['NFYB', 'CENPF', '1']
# single_pair ['MCM4', 'ID2', '0']
# single_pair ['KNTC1', 'CHEK2', '0']
# single_pair ['MCM7', 'UBE2T', '0']
# single_pair ['FOS', 'GRPR', '1']
# single_pair ['PTTG1', 'HAUS1', '0']
# single_pair ['KNTC1', 'ACTC1', '0']
# single_pair ['FOS', 'CACYBP', '1']
# single_pair ['FOS', 'RUVBL1', '0']
# single_pair ['ZNF143', 'CDC20', '0']
# single_pair ['DDIT3', 'PLCD1', '0']
# single_pair ['RUVBL1', 'CCNH', '0']
# single_pair ['ZNF143', 'CDK1', '0']
# single_pair ['OTX2', 'ZNF143', '0']
# single_pair ['FOS', 'UQCC1', '1']
# single_pair ['CRABP2', 'KLF6', '0']
# single_pair ['OTX2', 'CA2', '0']
# single_pair ['KNTC1', 'MCM3', '0']
# single_pair ['MCM4', 'LGALS3', '0']
# single_pair ['ID2', 'WARS', '0']
# single_pair ['KLF6', 'OTX2', '0']
# single_pair ['KLF6', 'PRMT5', '0']
# single_pair ['MCM3', 'MTFP1', '0']
# single_pair ['ID2', 'ANAPC7', '0']
# single_pair ['DDIT3', 'TNFRSF12A', '0']
# single_pair ['PTTG1', 'ICA1', '0']
# single_pair ['MCM7', 'KLF6', '0']
# single_pair ['DDIT3', 'SCHIP1', '0']
# single_pair ['ID3', 'ATG5', '0']
# single_pair ['MCM3', 'UQCC1', '0']
# single_pair ['KLF6', 'MTFP1', '0']
# single_pair ['MCM7', 'PTTG1', '0']
# single_pair ['FOS', 'KLF6', '1']
# single_pair ['ZNF143', 'DPYSL2', '0']
# single_pair ['MCM7', 'UTRN', '0']
# single_pair ['NFYB', 'CDK1', '0']
# single_pair ['PITX2', 'ACTL6A', '0']
# single_pair ['ID2', 'RBP4', '0']
# single_pair ['DDIT3', 'ICA1', '0']
# single_pair ['RUVBL1', 'SMYD3', '0']
# single_pair ['OTX2', 'KIF20B', '0']
# single_pair ['OTX2', 'CDC20', '0']
# single_pair ['ID2', 'UBE2T', '0']
# single_pair ['DDIT3', 'DKC1', '0']
# single_pair ['PITX2', 'ANAPC7', '0']
# single_pair ['DDIT3', 'CENPF', '0']
# single_pair ['FOS', 'MCM4', '0']
# single_pair ['KNTC1', 'NQO1', '0']
# single_pair ['OTX2', 'OCIAD2', '0']
# single_pair ['PITX2', 'CCNB1', '0']
# single_pair ['ID3', 'MRPS27', '0']
# single_pair ['NFYB', 'TM2D2', '0']
# single_pair ['KNTC1', 'CACYBP', '0']
# single_pair ['KNTC1', 'PLCD1', '0']
# single_pair ['MCM3', 'UBE2T', '0']
# single_pair ['PTTG1', 'ID3', '1']
# single_pair ['FOS', 'BUB1B', '0']
# single_pair ['TGIF1', 'ATG5', '0']
# single_pair ['TGIF1', 'TNFRSF12A', '0']
# single_pair ['MCM3', 'RBP4', '0']
# single_pair ['ID3', 'HAUS1', '0']
# single_pair ['PITX2', 'WARS', '0']
# single_pair ['ZNF143', 'ANXA3', '0']
# single_pair ['KLF6', 'CDK1', '0']
# single_pair ['MCM4', 'GRPR', '0']
# single_pair ['PITX2', 'TPD52L1', '0']
# single_pair ['RUVBL1', 'NQO1', '0']
# single_pair ['CRABP2', 'ATG5', '0']
# single_pair ['OTX2', 'CDK1', '0']
# single_pair ['RUVBL1', 'BUB1B', '0']
# single_pair ['TGIF1', 'PCNA', '0']
# single_pair ['MCM7', 'LGALS1', '0']
# single_pair ['OTX2', 'OTX2', '0']
# single_pair ['OTX2', 'PRKCE', '0']
# single_pair ['DDIT3', 'DPYSL2', '0']
# single_pair ['KNTC1', 'PTTG1', '0']
# single_pair ['KNTC1', 'WARS', '0']
# single_pair ['CRABP2', 'KIF20B', '0']
# single_pair ['CRABP2', 'SERPINB1', '0']
# single_pair ['ZNF143', 'F3', '0']
# single_pair ['DDIT3', 'ASNS', '1']
# single_pair ['MCM3', 'SMYD3', '0']
# single_pair ['DDIT3', 'PCNA', '0']
# single_pair ['KLF6', 'CA2', '0']
# single_pair ['KLF6', 'CCS', '0']
# single_pair ['MCM3', 'TM2D2', '0']
# single_pair ['PTTG1', 'CYP3A5', '0']
# single_pair ['CRABP2', 'PITX2', '0']
# single_pair ['TGIF1', 'KLF6', '0']
# single_pair ['KLF6', 'KIF20B', '0']
# single_pair ['MCM3', 'KIF20B', '0']
# single_pair ['RUVBL1', 'NFYB', '0']
# single_pair ['PITX2', 'CCS', '0']
# single_pair ['PTTG1', 'TNFRSF12A', '0']
# single_pair ['CRABP2', 'DPYSL2', '0']
# single_pair ['MCM7', 'ATG5', '0']
# single_pair ['ZNF143', 'CHEK2', '0']
# single_pair ['ZNF143', 'CA2', '0']
# single_pair ['TGIF1', 'CCL2', '0']
# single_pair ['ID3', 'PRMT5', '0']
# single_pair ['FOS', 'SCHIP1', '1']
# single_pair ['FOS', 'MCM3', '0']
# single_pair ['CRABP2', 'MCM7', '0']
# single_pair ['PTTG1', 'MCM4', '0']
# single_pair ['MCM7', 'PCNA', '0']
# single_pair ['MCM3', 'DPCD', '0']
# single_pair ['ID2', 'MCM7', '0']
# single_pair ['MCM7', 'ACTL6A', '0']
# single_pair ['MCM4', 'DDIT3', '0']
# single_pair ['RUVBL1', 'WARS', '0']
# single_pair ['NFYB', 'CYP3A5', '0']
# single_pair ['MCM7', 'UQCC1', '0']
# single_pair ['MCM4', 'GSN', '0']
# single_pair ['RUVBL1', 'CACYBP', '0']
# single_pair ['ID3', 'IQGAP2', '0']
# single_pair ['MCM4', 'ANXA3', '0']
# single_pair ['KLF6', 'GSN', '0']
# single_pair ['PTTG1', 'DPCD', '0']
# single_pair ['ZNF143', 'NIP7', '0']
# single_pair ['FOS', 'SERPINB1', '1']
# single_pair ['RUVBL1', 'KIF20B', '0']
# single_pair ['NFYB', 'CAMK2D', '0']
# single_pair ['MCM4', 'CYP3A5', '0']
# single_pair ['TGIF1', 'ID3', '0']
# single_pair ['KNTC1', 'CYP3A5', '0']
# single_pair ['PITX2', 'DDIT3', '0']
# single_pair ['ID2', 'KLF6', '0']
# single_pair ['KNTC1', 'FANCB', '0']
# single_pair ['PITX2', 'PTTG1', '0']
# single_pair ['KNTC1', 'RUVBL1', '0']
# single_pair ['PITX2', 'ATG5', '0']
# single_pair ['MCM3', 'IQGAP2', '0']
# single_pair ['KLF6', 'PCCA', '0']
# single_pair ['FOS', 'PLCD1', '1']
# single_pair ['MCM3', 'ID2', '0']
# single_pair ['OTX2', 'NEK2', '0']
# single_pair ['DDIT3', 'MCM7', '0']
# single_pair ['ID3', 'ACTC1', '0']
# single_pair ['CRABP2', 'ASNS', '0']
# single_pair ['CRABP2', 'VTN', '0']
# single_pair ['RUVBL1', 'ZNF143', '0']
# single_pair ['CRABP2', 'PLK1', '0']
# single_pair ['RUVBL1', 'CHEK2', '0']
# single_pair ['KNTC1', 'PIM2', '0']
# single_pair ['KNTC1', 'LGALS3', '0']
# single_pair ['ID2', 'PITX2', '0']
# single_pair ['PITX2', 'TNNI3', '0']
# single_pair ['RUVBL1', 'PLCD1', '0']
# single_pair ['RUVBL1', 'AURKA', '0']
# single_pair ['MCM4', 'OTX2', '0']
# single_pair ['MCM3', 'PTTG1', '0']
# single_pair ['MCM3', 'TNNI3', '0']
# single_pair ['ZNF143', 'FANCB', '0']
# single_pair ['TGIF1', 'ICA1', '0']
# single_pair ['RUVBL1', 'ID2', '0']
# single_pair ['TGIF1', 'BUB1B', '0']
# single_pair ['ID2', 'FANCB', '0']
# single_pair ['TGIF1', 'SCHIP1', '0']
# single_pair ['CRABP2', 'CCBL2', '0']
# single_pair ['OTX2', 'PTTG1', '0']
# single_pair ['FOS', 'PHF5A', '0']
# single_pair ['CRABP2', 'PMAIP1', '0']
# single_pair ['MCM4', 'PTTG1', '0']
# single_pair ['FOS', 'TNFRSF12A', '1']
# single_pair ['MCM3', 'DPYSL2', '0']
# single_pair ['PITX2', 'GPC3', '0']
# single_pair ['ID2', 'BUB1B', '0']
# single_pair ['PITX2', 'EFTUD2', '0']
# single_pair ['PITX2', 'CA2', '0']
# single_pair ['MCM3', 'HESX1', '0']
# single_pair ['MCM7', 'PMAIP1', '0']
# single_pair ['MCM3', 'GSN', '0']
# single_pair ['KNTC1', 'DPCD', '0']
# single_pair ['NFYB', 'NQO1', '0']
# single_pair ['NFYB', 'SMYD3', '0']
# single_pair ['KLF6', 'APEH', '0']
# single_pair ['TGIF1', 'ACTL6A', '0']
# single_pair ['KNTC1', 'KIF20B', '0']
# single_pair ['ID2', 'TNNI3', '0']
# single_pair ['ZNF143', 'LGALS1', '0']
# single_pair ['PITX2', 'PHF5A', '0']
# single_pair ['KLF6', 'SCHIP1', '0']
# single_pair ['NFYB', 'RBP4', '0']
# single_pair ['KLF6', 'VTN', '0']
# single_pair ['DDIT3', 'HESX1', '0']
# single_pair ['OTX2', 'CCBL2', '0']
# single_pair ['FOS', 'ACADVL', '1']
# single_pair ['CRABP2', 'AURKA', '0']
# single_pair ['PITX2', 'BUB1B', '0']
# single_pair ['TGIF1', 'WARS', '1']
# single_pair ['MCM7', 'CAPN12', '0']
# single_pair ['PITX2', 'ZWILCH', '0']
# single_pair ['ID2', 'OCIAD2', '0']
# single_pair ['ID2', 'CAPN12', '0']
# single_pair ['KLF6', 'DKC1', '0']
# single_pair ['MCM3', 'OTX2', '0']
# single_pair ['KNTC1', 'DDIT3', '0']
# single_pair ['ID2', 'OTX2', '0']
# single_pair ['KLF6', 'PITX2', '0']
# single_pair ['ID3', 'NFYB', '0']
# single_pair ['ZNF143', 'UTRN', '0']
# single_pair ['MCM4', 'OCIAD2', '0']
# single_pair ['ZNF143', 'NQO1', '0']
# single_pair ['CRABP2', 'TF', '0']
# single_pair ['FOS', 'CDC20', '0']
# single_pair ['MCM7', 'PITX2', '0']
# single_pair ['ID3', 'ID3', '1']
# single_pair ['MCM4', 'IQGAP2', '0']
# single_pair ['MCM7', 'FOS', '0']
# single_pair ['KNTC1', 'CDK1', '0']
# single_pair ['MCM7', 'HAUS1', '0']
# single_pair ['TGIF1', 'PMAIP1', '0']
# single_pair ['MCM7', 'MCM4', '1']
# single_pair ['ZNF143', 'PRKCE', '0']
# single_pair ['OTX2', 'F3', '0']
# single_pair ['DDIT3', 'CACYBP', '0']
# single_pair ['DDIT3', 'MCM4', '0']
# single_pair ['KLF6', 'BUB1B', '0']
# single_pair ['PITX2', 'HAUS1', '0']
# single_pair ['MCM4', 'SCHIP1', '0']
# single_pair ['MCM4', 'WARS', '0']
# single_pair ['TGIF1', 'UBE2T', '0']
# single_pair ['CRABP2', 'ACTL6A', '0']
# single_pair ['MCM7', 'PLCD1', '0']
# single_pair ['TGIF1', 'FOS', '0']
# single_pair ['PITX2', 'PCCA', '0']
# single_pair ['MCM4', 'CCBL2', '0']
# single_pair ['OTX2', 'CCNH', '0']
# single_pair ['TGIF1', 'PLCD1', '0']
# single_pair ['TGIF1', 'CCNH', '0']
# single_pair ['ID2', 'CCNB1', '0']
# single_pair ['MCM4', 'CENPF', '0']
# single_pair ['OTX2', 'CAMK2D', '0']
# single_pair ['ID2', 'CHEK2', '0']
# single_pair ['FOS', 'MTFP1', '1']
# single_pair ['MCM7', 'ICA1', '0']
# single_pair ['PITX2', 'SERPINB1', '0']
# single_pair ['NFYB', 'FANCB', '0']
# single_pair ['MCM3', 'TGIF1', '0']
# single_pair ['ID2', 'DPCD', '0']
# single_pair ['KLF6', 'F3', '0']
# single_pair ['TGIF1', 'PITX2', '0']
# single_pair ['FOS', 'CAPN12', '1']
# single_pair ['DDIT3', 'ID2', '1']
# single_pair ['TGIF1', 'CACYBP', '0']
# single_pair ['KNTC1', 'ZWILCH', '1']
# single_pair ['ID2', 'PIM2', '0']
# single_pair ['MCM7', 'TM2D2', '0']
# single_pair ['MCM3', 'PCCA', '0']
# single_pair ['PITX2', 'PRMT5', '0']
# single_pair ['KNTC1', 'AURKA', '0']
# single_pair ['NFYB', 'ANAPC7', '0']
# single_pair ['PTTG1', 'RUVBL1', '0']
# single_pair ['PITX2', 'DPYSL2', '0']
# single_pair ['ID3', 'CA2', '0']
# single_pair ['ID3', 'CACYBP', '0']
# single_pair ['PITX2', 'FOS', '0']
# single_pair ['DDIT3', 'F3', '0']
# single_pair ['RUVBL1', 'CRABP2', '0']
# single_pair ['CRABP2', 'ID3', '0']
# single_pair ['ID2', 'APEH', '0']
# single_pair ['FOS', 'RBP4', '1']
# single_pair ['TGIF1', 'TM2D2', '0']
# single_pair ['ID3', 'CCBL2', '0']
# single_pair ['KNTC1', 'CCBL2', '0']
# single_pair ['PTTG1', 'MCM7', '0']
# single_pair ['RUVBL1', 'CCL2', '0']
# single_pair ['ID2', 'HESX1', '0']
# single_pair ['PITX2', 'LGALS1', '0']
# single_pair ['FOS', 'CDK1', '0']
# single_pair ['NFYB', 'IQGAP2', '0']
# single_pair ['ID3', 'PLCD1', '0']
# single_pair ['TGIF1', 'CRABP2', '0']
# single_pair ['RUVBL1', 'OTX2', '0']
# single_pair ['TGIF1', 'GPC3', '1']
# single_pair ['ZNF143', 'ZNF143', '0']
# single_pair ['MCM4', 'EFTUD2', '0']
# single_pair ['KNTC1', 'CCNH', '0']
# single_pair ['MCM3', 'ASNS', '0']
# single_pair ['TGIF1', 'RUVBL1', '0']
# single_pair ['KLF6', 'CCBL2', '0']
# single_pair ['OTX2', 'VTN', '0']
# single_pair ['ID3', 'GSN', '0']
# single_pair ['ID3', 'DKC1', '0']
# single_pair ['NFYB', 'CACYBP', '0']
# single_pair ['MCM4', 'CCS', '0']
# single_pair ['FOS', 'TGIF1', '1']
# single_pair ['DDIT3', 'PMAIP1', '0']
# single_pair ['PTTG1', 'ZNF143', '0']
# single_pair ['ID3', 'PLK1', '0']
# single_pair ['DDIT3', 'CAMK2D', '0']
# single_pair ['CRABP2', 'IQGAP2', '0']
# single_pair ['FOS', 'CCS', '0']
# single_pair ['ZNF143', 'PIM2', '0']
# single_pair ['MCM7', 'ID2', '0']
# single_pair ['KNTC1', 'CCL2', '0']
# single_pair ['KNTC1', 'MCM4', '0']
# single_pair ['FOS', 'UTRN', '1']
# single_pair ['ID3', 'ADM', '0']
# single_pair ['DDIT3', 'NQO1', '0']
# single_pair ['PITX2', 'LGALS3', '0']
# single_pair ['ID3', 'FOS', '0']
# single_pair ['ID2', 'CCNH', '0']
# single_pair ['PTTG1', 'TNNI3', '0']
# single_pair ['OTX2', 'TPD52L1', '0']
# single_pair ['CRABP2', 'HAUS1', '0']
# single_pair ['PITX2', 'TM2D2', '0']
# single_pair ['ID2', 'PRMT5', '0']
# single_pair ['FOS', 'ZNF143', '0']
# single_pair ['DDIT3', 'GSN', '0']
# single_pair ['NFYB', 'ADM', '0']
# single_pair ['KLF6', 'PLK1', '0']
# single_pair ['ZNF143', 'CCNH', '0']
# single_pair ['KLF6', 'TM2D2', '0']
# single_pair ['OTX2', 'DPYSL2', '0']
# single_pair ['PITX2', 'CACYBP', '0']
# single_pair ['CRABP2', 'HESX1', '0']
# single_pair ['RUVBL1', 'ID3', '0']
# single_pair ['ID2', 'ICA1', '0']
# single_pair ['ID2', 'F3', '0']
# single_pair ['MCM4', 'MTFP1', '0']
# single_pair ['KLF6', 'PMAIP1', '1']
# single_pair ['KNTC1', 'ACTL6A', '0']
# single_pair ['MCM3', 'CAPN12', '0']
# single_pair ['PITX2', 'PMAIP1', '0']
# single_pair ['PTTG1', 'TM2D2', '0']
# single_pair ['MCM3', 'PLCD1', '0']
# single_pair ['OTX2', 'TF', '0']
# single_pair ['RUVBL1', 'OCIAD2', '0']
# single_pair ['PTTG1', 'PCNA', '0']
# single_pair ['ZNF143', 'MTFP1', '0']
# single_pair ['MCM4', 'CAPN12', '0']
# single_pair ['MCM3', 'CAMK2D', '0']
# single_pair ['DDIT3', 'RBP4', '0']
# single_pair ['DDIT3', 'CDK1', '0']
# single_pair ['PITX2', 'CYP3A5', '0']
# single_pair ['FOS', 'CYP3A5', '1']
# single_pair ['CRABP2', 'F3', '0']
# single_pair ['KNTC1', 'DKC1', '0']
# single_pair ['KLF6', 'CACYBP', '0']
# single_pair ['MCM4', 'CHEK2', '0']
# single_pair ['ID2', 'CDC20', '0']
# single_pair ['OTX2', 'PCNA', '0']
# single_pair ['CRABP2', 'PCCA', '0']
# single_pair ['KLF6', 'HAUS1', '0']
# single_pair ['RUVBL1', 'MRPS27', '0']
# single_pair ['ZNF143', 'ADM', '0']
# single_pair ['ID2', 'TGIF1', '0']
# single_pair ['RUVBL1', 'EFTUD2', '0']
# single_pair ['MCM4', 'NIP7', '0']
# single_pair ['CRABP2', 'NIP7', '0']
# single_pair ['ZNF143', 'CENPF', '0']
# single_pair ['NFYB', 'TNFRSF12A', '0']
# single_pair ['ID2', 'ID3', '0']
# single_pair ['KNTC1', 'PLK1', '0']
# single_pair ['KLF6', 'OCIAD2', '0']
# single_pair ['DDIT3', 'OTX2', '0']
# single_pair ['TGIF1', 'DDIT3', '0']
# single_pair ['OTX2', 'CCS', '0']
# single_pair ['NFYB', 'F3', '0']
# single_pair ['PTTG1', 'CCNB1', '1']
# single_pair ['ID3', 'PITX2', '0']
# single_pair ['ZNF143', 'PMAIP1', '0']
# single_pair ['PITX2', 'UQCC1', '0']
# single_pair ['OTX2', 'MCM7', '0']
# single_pair ['TGIF1', 'NIP7', '0']
# single_pair ['ZNF143', 'TNNI3', '0']
# single_pair ['OTX2', 'MCM3', '0']
# single_pair ['TGIF1', 'LGALS1', '0']
# single_pair ['KNTC1', 'ATG5', '0']
# single_pair ['CRABP2', 'RBP4', '0']
# single_pair ['ZNF143', 'TPD52L1', '0']
# single_pair ['OTX2', 'LGALS1', '0']
# single_pair ['PTTG1', 'GPC3', '0']
# single_pair ['DDIT3', 'KNTC1', '0']
# single_pair ['OTX2', 'UQCC1', '0']
# single_pair ['RUVBL1', 'FOS', '0']
# single_pair ['CRABP2', 'BUB1B', '0']
# single_pair ['ZNF143', 'PHF5A', '0']
# single_pair ['KLF6', 'ACADVL', '0']
# single_pair ['ZNF143', 'NIF3L1', '0']
# single_pair ['KNTC1', 'MRPS27', '0']
# single_pair ['KLF6', 'KNTC1', '0']
# single_pair ['FOS', 'TM2D2', '1']
# single_pair ['ZNF143', 'SMYD3', '0']
# single_pair ['PITX2', 'ANXA3', '0']
# single_pair ['FOS', 'APEH', '0']
# single_pair ['ID2', 'GRPR', '0']
# single_pair ['KLF6', 'MCM3', '0']
# single_pair ['RUVBL1', 'PRMT5', '0']
# single_pair ['PITX2', 'PIM2', '0']
# single_pair ['ZNF143', 'WARS', '0']
# single_pair ['OTX2', 'PLCD1', '0']
# single_pair ['RUVBL1', 'DPCD', '0']
# single_pair ['MCM7', 'PHF5A', '0']
# single_pair ['KLF6', 'ACTL6A', '0']
# single_pair ['RUVBL1', 'IQGAP2', '0']
# single_pair ['RUVBL1', 'MCM4', '0']
# single_pair ['MCM4', 'ADM', '0']
# single_pair ['MCM4', 'VTN', '0']
# single_pair ['TGIF1', 'NEK2', '0']
# single_pair ['DDIT3', 'APEH', '1']
# single_pair ['DDIT3', 'PCCA', '0']
# single_pair ['MCM4', 'CA2', '0']
# single_pair ['ZNF143', 'MCM7', '0']
# single_pair ['DDIT3', 'TM2D2', '0']
# single_pair ['MCM7', 'HESX1', '0']
# single_pair ['PITX2', 'ICA1', '0']
# single_pair ['ID2', 'PCNA', '0']
# single_pair ['FOS', 'ID3', '0']
# single_pair ['ID2', 'CAMK2D', '0']
# single_pair ['KLF6', 'RBP4', '0']
# single_pair ['MCM7', 'TNNI3', '0']
# single_pair ['PITX2', 'VTN', '0']
# single_pair ['KLF6', 'HESX1', '0']
# single_pair ['MCM3', 'CRABP2', '0']
# single_pair ['ID3', 'CCL2', '0']
# single_pair ['KNTC1', 'CA2', '0']
# single_pair ['RUVBL1', 'DPYSL2', '0']
# single_pair ['TGIF1', 'ANAPC7', '0']
# single_pair ['TGIF1', 'EFTUD2', '0']
# single_pair ['PITX2', 'KIF20B', '0']
# single_pair ['FOS', 'OTX2', '0']
# single_pair ['ID3', 'RBP4', '0']
# single_pair ['DDIT3', 'TNNI3', '0']
# single_pair ['KNTC1', 'SERPINB1', '0']
# single_pair ['FOS', 'MRPS27', '0']
# single_pair ['KNTC1', 'CDC20', '0']
# single_pair ['MCM7', 'CCS', '0']
# single_pair ['RUVBL1', 'SERPINB1', '0']
# single_pair ['FOS', 'CAMK2D', '1']
# single_pair ['FOS', 'KNTC1', '0']
# single_pair ['OTX2', 'UTRN', '0']
# single_pair ['RUVBL1', 'MCM3', '0']
# single_pair ['NFYB', 'HAUS1', '0']
# single_pair ['CRABP2', 'DKC1', '0']
# single_pair ['OTX2', 'GSN', '0']
# single_pair ['NFYB', 'TF', '0']
# single_pair ['ID2', 'TNFRSF12A', '0']
# single_pair ['MCM4', 'ASNS', '0']
# single_pair ['ID3', 'ASNS', '0']
# single_pair ['CRABP2', 'ZWILCH', '0']
# single_pair ['FOS', 'GSN', '1']
# single_pair ['PTTG1', 'PIM2', '0']
# single_pair ['ID3', 'TM2D2', '0']
# single_pair ['TGIF1', 'CAMK2D', '0']
# single_pair ['PITX2', 'OTX2', '0']
# single_pair ['ID3', 'DDIT3', '0']
# single_pair ['ID2', 'ASNS', '0']
# single_pair ['RUVBL1', 'ZWILCH', '0']
# single_pair ['DDIT3', 'UBE2T', '0']
# single_pair ['KNTC1', 'OTX2', '0']
# single_pair ['TGIF1', 'GSN', '0']
# single_pair ['DDIT3', 'NIF3L1', '0']
# single_pair ['RUVBL1', 'DDIT3', '0']
# single_pair ['KNTC1', 'NFYB', '0']
# single_pair ['MCM7', 'PCCA', '0']
# single_pair ['ID3', 'PCCA', '0']
# single_pair ['MCM3', 'PITX2', '0']
# single_pair ['MCM4', 'ICA1', '0']
# single_pair ['KNTC1', 'DPYSL2', '0']
# single_pair ['KLF6', 'MCM4', '0']
# single_pair ['OTX2', 'ICA1', '0']
# single_pair ['MCM7', 'MCM3', '1']
# single_pair ['KLF6', 'NFYB', '0']
# single_pair ['RUVBL1', 'CDC20', '0']
# single_pair ['PITX2', 'CDC20', '0']
# single_pair ['MCM4', 'PCNA', '0']
# single_pair ['OTX2', 'KNTC1', '0']
# single_pair ['MCM3', 'ID3', '0']
# single_pair ['PITX2', 'RUVBL1', '0']
# single_pair ['MCM7', 'ADM', '0']
# single_pair ['CRABP2', 'PLCD1', '0']
# single_pair ['CRABP2', 'MCM3', '0']
# single_pair ['ID3', 'LGALS1', '0']
# single_pair ['OTX2', 'TGIF1', '0']
# single_pair ['OTX2', 'CCNB1', '0']
# single_pair ['CRABP2', 'CDC20', '0']
# single_pair ['MCM3', 'CDK1', '0']
# single_pair ['ID3', 'ZWILCH', '0']
# single_pair ['RUVBL1', 'CCNB1', '0']
# single_pair ['DDIT3', 'NEK2', '0']
# single_pair ['RUVBL1', 'GRPR', '0']
# single_pair ['KNTC1', 'GPC3', '0']
# single_pair ['OTX2', 'ID3', '0']
# single_pair ['OTX2', 'MTFP1', '0']
# single_pair ['OTX2', 'ANAPC7', '0']
# single_pair ['OTX2', 'WARS', '0']
# single_pair ['RUVBL1', 'KNTC1', '0']
# single_pair ['ID3', 'CHEK2', '0']
# single_pair ['KLF6', 'ADM', '0']
# single_pair ['CRABP2', 'DPCD', '0']
# single_pair ['OTX2', 'EFTUD2', '0']
# single_pair ['KNTC1', 'TNNI3', '0']
# single_pair ['MCM7', 'TPD52L1', '0']
# single_pair ['NFYB', 'KNTC1', '0']
# single_pair ['PTTG1', 'PITX2', '0']
# single_pair ['TGIF1', 'PTTG1', '0']
# single_pair ['ZNF143', 'SERPINB1', '0']
# single_pair ['NFYB', 'DKC1', '0']
# single_pair ['RUVBL1', 'ACADVL', '0']
# single_pair ['FOS', 'TNNI3', '1']
# single_pair ['ID3', 'UTRN', '0']
# single_pair ['MCM3', 'TNFRSF12A', '0']
# single_pair ['MCM4', 'KNTC1', '0']
# single_pair ['KNTC1', 'TPD52L1', '0']
# single_pair ['KLF6', 'TNNI3', '0']
# single_pair ['KNTC1', 'TGIF1', '0']
# single_pair ['CRABP2', 'CACYBP', '0']
# single_pair ['ID3', 'F3', '0']
# single_pair ['MCM7', 'ACTC1', '0']
# single_pair ['MCM7', 'CHEK2', '0']
# single_pair ['DDIT3', 'ATG5', '1']
# single_pair ['CRABP2', 'PRMT5', '0']
# single_pair ['CRABP2', 'LGALS3', '0']
# single_pair ['OTX2', 'ATG5', '0']
# single_pair ['ID2', 'NEK2', '0']
# single_pair ['ID3', 'ACADVL', '0']
# single_pair ['NFYB', 'HESX1', '0']
# single_pair ['CRABP2', 'GPC3', '0']
# single_pair ['TGIF1', 'MTFP1', '0']
# single_pair ['ZNF143', 'PLCD1', '0']
# single_pair ['KNTC1', 'IQGAP2', '0']
# single_pair ['ID3', 'CCNB1', '0']
# single_pair ['PITX2', 'ACADVL', '0']
# single_pair ['NFYB', 'SERPINB1', '0']
# single_pair ['ID2', 'HAUS1', '0']
# single_pair ['PITX2', 'KNTC1', '0']
# single_pair ['ZNF143', 'ACTL6A', '0']
# single_pair ['KNTC1', 'HAUS1', '0']
# single_pair ['MCM7', 'ZWILCH', '0']
# single_pair ['ZNF143', 'ID2', '0']
# single_pair ['MCM3', 'FOS', '0']
# single_pair ['OTX2', 'KLF6', '0']
# single_pair ['RUVBL1', 'NEK2', '0']
# single_pair ['ID3', 'PRKCE', '0']
# single_pair ['MCM3', 'PRKCE', '0']
# single_pair ['ID2', 'NQO1', '0']
# single_pair ['CRABP2', 'PCNA', '0']
# single_pair ['MCM7', 'NIF3L1', '0']
# single_pair ['DDIT3', 'ZWILCH', '0']
# single_pair ['PITX2', 'RBP4', '0']
# single_pair ['TGIF1', 'CHEK2', '0']
# single_pair ['MCM7', 'PRKCE', '0']
# single_pair ['CRABP2', 'ACTC1', '0']
# single_pair ['KNTC1', 'HESX1', '0']
# single_pair ['ID3', 'TF', '0']
# single_pair ['FOS', 'NQO1', '1']
# single_pair ['PTTG1', 'TGIF1', '0']
# single_pair ['ID3', 'PIM2', '0']
# single_pair ['KNTC1', 'ASNS', '0']
# single_pair ['PITX2', 'GRPR', '0']
# single_pair ['PTTG1', 'BUB1B', '0']
# single_pair ['DDIT3', 'LGALS3', '0']
# single_pair ['PTTG1', 'ACTC1', '0']
# single_pair ['KLF6', 'CENPF', '0']
# single_pair ['CRABP2', 'KNTC1', '0']
# single_pair ['TGIF1', 'AURKA', '0']
# single_pair ['MCM3', 'CYP3A5', '0']
# single_pair ['OTX2', 'GPC3', '0']
# single_pair ['ID2', 'GSN', '0']
# single_pair ['PTTG1', 'FANCB', '0']
# single_pair ['MCM3', 'TF', '0']
# single_pair ['KLF6', 'CAMK2D', '0']
# single_pair ['TGIF1', 'MCM4', '0']
# single_pair ['OTX2', 'CRABP2', '0']
# single_pair ['OTX2', 'NFYB', '0']
# single_pair ['NFYB', 'EFTUD2', '0']
# single_pair ['ID2', 'GPC3', '0']
# single_pair ['FOS', 'ICA1', '1']
# single_pair ['CRABP2', 'UQCC1', '0']
# single_pair ['DDIT3', 'PIM2', '0']
# single_pair ['NFYB', 'ZWILCH', '0']
# single_pair ['MCM4', 'KLF6', '0']
# single_pair ['DDIT3', 'SMYD3', '0']
# single_pair ['ZNF143', 'ANAPC7', '0']
# single_pair ['ZNF143', 'OCIAD2', '0']
# single_pair ['CRABP2', 'CENPF', '0']
# single_pair ['PTTG1', 'PRKCE', '0']
# single_pair ['FOS', 'PMAIP1', '0']
# single_pair ['OTX2', 'PITX2', '0']
# single_pair ['TGIF1', 'CCNB1', '0']
# single_pair ['ID3', 'CCNH', '0']
# single_pair ['ID2', 'CENPF', '0']
# single_pair ['DDIT3', 'NFYB', '0']
# single_pair ['MCM7', 'PIM2', '0']
# single_pair ['NFYB', 'PHF5A', '1']
# single_pair ['RUVBL1', 'UQCC1', '0']
# single_pair ['MCM4', 'PLCD1', '0']
# single_pair ['MCM3', 'MCM4', '1']
# single_pair ['PITX2', 'MCM7', '0']
# single_pair ['PITX2', 'CHEK2', '0']
# single_pair ['MCM3', 'CCBL2', '0']
# single_pair ['MCM4', 'SERPINB1', '0']
# single_pair ['KNTC1', 'NIP7', '0']
# single_pair ['MCM7', 'FANCB', '0']
# single_pair ['DDIT3', 'UTRN', '0']
# single_pair ['NFYB', 'CRABP2', '0']
# single_pair ['KNTC1', 'APEH', '0']
# single_pair ['NFYB', 'ICA1', '0']
# single_pair ['MCM7', 'MT2A', '0']
# single_pair ['FOS', 'NFYB', '0']
# single_pair ['PITX2', 'ID2', '0']
# single_pair ['CRABP2', 'CCNH', '0']
# single_pair ['MCM3', 'ZWILCH', '0']
# single_pair ['DDIT3', 'PITX2', '0']
# single_pair ['PTTG1', 'CENPF', '0']
# single_pair ['PTTG1', 'PHF5A', '0']
# single_pair ['ID2', 'AURKA', '0']
# single_pair ['TGIF1', 'DKC1', '0']
# single_pair ['ZNF143', 'ZWILCH', '0']
# single_pair ['MCM7', 'OTX2', '0']
# single_pair ['ID2', 'TF', '0']
# single_pair ['MCM3', 'PLK1', '1']
# single_pair ['MCM4', 'CCL2', '0']
# single_pair ['KNTC1', 'NEK2', '0']
# single_pair ['ID3', 'LGALS3', '0']
# single_pair ['MCM7', 'RUVBL1', '0']
# single_pair ['ID2', 'MT2A', '0']
# single_pair ['MCM7', 'EFTUD2', '0']
# single_pair ['ZNF143', 'HAUS1', '0']
# single_pair ['FOS', 'LGALS3', '1']
# single_pair ['KNTC1', 'CCS', '0']
# single_pair ['NFYB', 'ID2', '0']
# single_pair ['NFYB', 'MCM4', '0']
# single_pair ['TGIF1', 'PHF5A', '0']
# single_pair ['ID3', 'CENPF', '0']
# single_pair ['KNTC1', 'ID2', '0']
# single_pair ['TGIF1', 'CDK1', '0']
# single_pair ['DDIT3', 'EFTUD2', '0']
# single_pair ['MCM3', 'F3', '0']
# single_pair ['RUVBL1', 'ASNS', '0']
# single_pair ['TGIF1', 'GRPR', '0']
# single_pair ['CRABP2', 'FOS', '0']
# single_pair ['TGIF1', 'CA2', '0']
# single_pair ['NFYB', 'PTTG1', '0']
# single_pair ['RUVBL1', 'PRKCE', '0']
# single_pair ['ZNF143', 'CAMK2D', '0']
# single_pair ['ID2', 'DDIT3', '0']
# single_pair ['MCM7', 'ASNS', '0']
# single_pair ['ID2', 'ID2', '1']
# single_pair ['DDIT3', 'MCM3', '0']
# single_pair ['CRABP2', 'EFTUD2', '0']
# single_pair ['MCM3', 'KLF6', '0']
# single_pair ['DDIT3', 'CCNB1', '0']
# single_pair ['ZNF143', 'CCS', '0']
# single_pair ['NFYB', 'CCBL2', '0']
# single_pair ['MCM4', 'CCNB1', '0']
# single_pair ['ID3', 'UQCC1', '0']
# single_pair ['MCM3', 'CCNB1', '0']
# single_pair ['RUVBL1', 'CCBL2', '0']
# single_pair ['PTTG1', 'KIF20B', '0']
# single_pair ['FOS', 'ACTC1', '0']
# single_pair ['TGIF1', 'FANCB', '0']
# single_pair ['MCM3', 'UTRN', '0']
# single_pair ['KNTC1', 'ZNF143', '0']
# single_pair ['RUVBL1', 'ANAPC7', '0']
# single_pair ['MCM3', 'CACYBP', '0']
# single_pair ['MCM3', 'AURKA', '0']
# single_pair ['ID2', 'DPYSL2', '0']
# single_pair ['CRABP2', 'CHEK2', '0']
# single_pair ['PTTG1', 'CRABP2', '0']
# single_pair ['PTTG1', 'LGALS3', '0']
# single_pair ['PTTG1', 'PLCD1', '0']
# single_pair ['RUVBL1', 'DKC1', '1']
# single_pair ['PTTG1', 'CDC20', '1']
# single_pair ['NFYB', 'APEH', '0']
# single_pair ['FOS', 'KIF20B', '1']
# single_pair ['MCM7', 'DKC1', '0']
# single_pair ['TGIF1', 'DPYSL2', '0']
# single_pair ['TGIF1', 'TNNI3', '0']
# single_pair ['ZNF143', 'NEK2', '0']
# single_pair ['ZNF143', 'EFTUD2', '0']
# single_pair ['RUVBL1', 'ACTL6A', '1']
# single_pair ['PITX2', 'PCNA', '0']
# single_pair ['NFYB', 'UBE2T', '1']
# single_pair ['KNTC1', 'EFTUD2', '0']
# single_pair ['ZNF143', 'LGALS3', '0']
# single_pair ['KNTC1', 'MT2A', '0']
# single_pair ['PTTG1', 'SCHIP1', '0']
# single_pair ['DDIT3', 'LGALS1', '0']
# single_pair ['DDIT3', 'DDIT3', '0']
# single_pair ['PITX2', 'PRKCE', '0']
# single_pair ['RUVBL1', 'F3', '0']
# single_pair ['OTX2', 'ANXA3', '0']
# single_pair ['RUVBL1', 'PCCA', '0']
# single_pair ['DDIT3', 'CCBL2', '0']
# single_pair ['KNTC1', 'PCNA', '0']
# single_pair ['PITX2', 'CCL2', '0']
# single_pair ['OTX2', 'NIF3L1', '0']
# single_pair ['OTX2', 'MT2A', '0']
# single_pair ['ZNF143', 'CRABP2', '0']
# single_pair ['RUVBL1', 'RUVBL1', '0']
# single_pair ['OTX2', 'CYP3A5', '0']
# single_pair ['MCM7', 'TNFRSF12A', '0']
# single_pair ['CRABP2', 'ZNF143', '0']
# single_pair ['ID3', 'DPCD', '0']
# single_pair ['MCM4', 'UBE2T', '0']
# single_pair ['TGIF1', 'PRKCE', '0']
# single_pair ['RUVBL1', 'TM2D2', '0']
# single_pair ['MCM3', 'PRMT5', '0']
# single_pair ['RUVBL1', 'ATG5', '0']
# single_pair ['KLF6', 'FOS', '0']
# single_pair ['DDIT3', 'KIF20B', '0']
# single_pair ['KLF6', 'UBE2T', '0']
# single_pair ['ZNF143', 'PLK1', '0']
# single_pair ['ID2', 'MRPS27', '0']
# single_pair ['RUVBL1', 'UBE2T', '0']
# single_pair ['ID3', 'CCS', '0']
# single_pair ['KNTC1', 'VTN', '0']
# single_pair ['OTX2', 'SMYD3', '0']
# single_pair ['FOS', 'PRMT5', '0']
# single_pair ['KNTC1', 'BUB1B', '0']
# single_pair ['ZNF143', 'ASNS', '0']
# single_pair ['KLF6', 'KLF6', '0']
# single_pair ['KLF6', 'TF', '0']
# single_pair ['DDIT3', 'CAPN12', '0']
# single_pair ['RUVBL1', 'RBP4', '0']
# single_pair ['MCM4', 'MCM4', '1']
# single_pair ['TGIF1', 'PRMT5', '1']
# single_pair ['TGIF1', 'SERPINB1', '0']
# single_pair ['KNTC1', 'TNFRSF12A', '0']
# single_pair ['TGIF1', 'LGALS3', '0']
# single_pair ['NFYB', 'CA2', '0']
# single_pair ['NFYB', 'GPC3', '0']
# single_pair ['PITX2', 'CCNH', '0']
# single_pair ['PTTG1', 'MT2A', '0']
# single_pair ['MCM4', 'CDC20', '0']
# single_pair ['ID2', 'TM2D2', '0']
# single_pair ['NFYB', 'MT2A', '0']
# single_pair ['ID2', 'KNTC1', '0']
# single_pair ['NFYB', 'LGALS3', '0']
# single_pair ['ID2', 'PRKCE', '0']
# single_pair ['KNTC1', 'PCCA', '0']
# single_pair ['OTX2', 'GRPR', '0']
# single_pair ['MCM4', 'DPCD', '0']
# single_pair ['DDIT3', 'CA2', '0']
# single_pair ['OTX2', 'CAPN12', '0']
# single_pair ['ID3', 'ZNF143', '0']
# single_pair ['DDIT3', 'PHF5A', '0']
# single_pair ['OTX2', 'DDIT3', '0']
# single_pair ['PITX2', 'ZNF143', '0']
# single_pair ['CRABP2', 'APEH', '0']
# single_pair ['NFYB', 'CCNH', '0']
# single_pair ['KNTC1', 'ANAPC7', '0']
# single_pair ['ID2', 'CCL2', '0']
# single_pair ['CRABP2', 'DDIT3', '0']
# single_pair ['DDIT3', 'HAUS1', '0']
# single_pair ['FOS', 'ANAPC7', '0']
# single_pair ['TGIF1', 'KNTC1', '0']
# single_pair ['MCM4', 'MT2A', '0']
# single_pair ['DDIT3', 'TGIF1', '0']
# single_pair ['MCM3', 'ICA1', '0']
# single_pair ['KNTC1', 'OCIAD2', '0']
# single_pair ['DDIT3', 'AURKA', '0']
# single_pair ['KLF6', 'CCL2', '0']
# single_pair ['MCM7', 'CCNB1', '0']
# single_pair ['NFYB', 'PIM2', '0']
# single_pair ['MCM4', 'CRABP2', '0']
# single_pair ['PTTG1', 'F3', '0']
# single_pair ['ID2', 'CDK1', '0']
# single_pair ['KLF6', 'RUVBL1', '0']
# single_pair ['MCM4', 'HAUS1', '0']
# single_pair ['DDIT3', 'ZNF143', '0']
# single_pair ['FOS', 'MCM7', '0']
# single_pair ['PITX2', 'SCHIP1', '0']
# single_pair ['MCM4', 'AURKA', '0']
# single_pair ['KLF6', 'ASNS', '0']
# single_pair ['MCM4', 'ACTL6A', '0']
# single_pair ['MCM7', 'MCM7', '1']
# single_pair ['FOS', 'EFTUD2', '1']
# single_pair ['PTTG1', 'APEH', '0']
# single_pair ['TGIF1', 'UTRN', '0']
# single_pair ['MCM7', 'GRPR', '0']
# single_pair ['KLF6', 'CHEK2', '0']
# single_pair ['FOS', 'IQGAP2', '0']
# single_pair ['ZNF143', 'CCNB1', '0']
# single_pair ['MCM3', 'MRPS27', '0']
# single_pair ['PITX2', 'UTRN', '0']
# single_pair ['KLF6', 'NEK2', '0']
# single_pair ['ZNF143', 'KLF6', '0']
# single_pair ['MCM7', 'NEK2', '0']
# single_pair ['ZNF143', 'PITX2', '0']
# single_pair ['KLF6', 'GRPR', '0']
# single_pair ['MCM3', 'CDC20', '0']
# single_pair ['CRABP2', 'ID2', '0']
# single_pair ['RUVBL1', 'PMAIP1', '0']
# single_pair ['ID3', 'FANCB', '0']
# single_pair ['NFYB', 'ACADVL', '0']
# single_pair ['DDIT3', 'KLF6', '0']
# single_pair ['FOS', 'SMYD3', '1']
# single_pair ['PITX2', 'FANCB', '0']
# single_pair ['ID3', 'PHF5A', '0']
# single_pair ['OTX2', 'RBP4', '0']
# single_pair ['RUVBL1', 'MT2A', '0']
# single_pair ['CRABP2', 'OCIAD2', '0']
# single_pair ['PTTG1', 'PTTG1', '0']
# single_pair ['ID2', 'PHF5A', '0']
# single_pair ['PTTG1', 'ASNS', '0']
# single_pair ['FOS', 'ID2', '0']
# single_pair ['PITX2', 'CCBL2', '0']
# single_pair ['CRABP2', 'UTRN', '0']
# single_pair ['KLF6', 'ANAPC7', '0']
# single_pair ['RUVBL1', 'PIM2', '0']
# single_pair ['TGIF1', 'PCCA', '0']
# single_pair ['ID2', 'PLCD1', '0']
# single_pair ['NFYB', 'PCCA', '0']
# single_pair ['KLF6', 'LGALS3', '0']
# single_pair ['PITX2', 'KLF6', '0']
# single_pair ['PTTG1', 'CDK1', '1']
# single_pair ['PTTG1', 'ANAPC7', '1']
# single_pair ['KNTC1', 'UBE2T', '0']
# single_pair ['TGIF1', 'HESX1', '0']
# single_pair ['KLF6', 'PCNA', '0']
# single_pair ['PTTG1', 'CACYBP', '0']
# single_pair ['PTTG1', 'CAMK2D', '0']
# single_pair ['RUVBL1', 'NIP7', '0']
# single_pair ['ID2', 'CRABP2', '0']
# single_pair ['KLF6', 'CDC20', '0']
# single_pair ['FOS', 'CA2', '1']
# single_pair ['CRABP2', 'SMYD3', '0']
# single_pair ['ZNF143', 'PTTG1', '0']
# single_pair ['OTX2', 'SCHIP1', '0']
# single_pair ['MCM4', 'HESX1', '0']
# single_pair ['ID3', 'GRPR', '0']
# single_pair ['ZNF143', 'FOS', '0']
# single_pair ['PITX2', 'F3', '0']
# single_pair ['OTX2', 'NQO1', '0']
# single_pair ['ID3', 'KIF20B', '0']
# single_pair ['MCM7', 'RBP4', '0']
# single_pair ['MCM4', 'CAMK2D', '0']
# single_pair ['MCM4', 'PIM2', '0']
# single_pair ['ID2', 'ADM', '0']
# single_pair ['ID3', 'MT2A', '0']
# single_pair ['MCM4', 'GPC3', '0']
# single_pair ['NFYB', 'PITX2', '0']
# single_pair ['CRABP2', 'PIM2', '0']
# single_pair ['CRABP2', 'CDK1', '0']
# single_pair ['MCM7', 'OCIAD2', '0']
# single_pair ['MCM4', 'CDK1', '1']
# single_pair ['FOS', 'CCL2', '1']
# single_pair ['PTTG1', 'TPD52L1', '0']
# single_pair ['RUVBL1', 'TF', '0']
# single_pair ['ID3', 'WARS', '0']
# single_pair ['CRABP2', 'MTFP1', '0']
# single_pair ['PITX2', 'ID3', '0']
# single_pair ['KLF6', 'SERPINB1', '0']
# single_pair ['KNTC1', 'TM2D2', '0']
# single_pair ['DDIT3', 'PRMT5', '0']
# single_pair ['MCM7', 'IQGAP2', '0']
# single_pair ['OTX2', 'PIM2', '0']
# single_pair ['KLF6', 'PTTG1', '1']
# single_pair ['FOS', 'LGALS1', '0']
# single_pair ['FOS', 'AURKA', '0']
# single_pair ['MCM4', 'NFYB', '0']
# single_pair ['PITX2', 'GSN', '0']
# single_pair ['PTTG1', 'UTRN', '0']
# single_pair ['PITX2', 'MT2A', '0']
# single_pair ['PTTG1', 'UQCC1', '0']
# single_pair ['MCM7', 'ID3', '0']
# single_pair ['DDIT3', 'BUB1B', '0']
# single_pair ['DDIT3', 'FOS', '1']
# single_pair ['CRABP2', 'NFYB', '0']
# single_pair ['KLF6', 'LGALS1', '0']
# single_pair ['MCM7', 'CA2', '0']
# single_pair ['KLF6', 'EFTUD2', '0']
# single_pair ['RUVBL1', 'ICA1', '0']
# single_pair ['MCM4', 'ATG5', '0']
# single_pair ['KLF6', 'CCNH', '0']
# single_pair ['OTX2', 'ASNS', '0']
# All genes:61
# TFs:13
# len(single_pair) 3
# Generating matrix of gene pair 0 0
# Generating matrix of gene pair 0 1
# Generating matrix of gene pair 0 2
# Generating matrix of gene pair 0 3
# Generating matrix of gene pair 0 4
# Generating matrix of gene pair 0 5
# Generating matrix of gene pair 0 6
# Generating matrix of gene pair 0 7
# Generating matrix of gene pair 0 8
# Generating matrix of gene pair 0 9
# Generating matrix of gene pair 0 10
# Generating matrix of gene pair 0 11
# Generating matrix of gene pair 0 12
# Generating matrix of gene pair 0 13
# Generating matrix of gene pair 0 14
# Generating matrix of gene pair 0 15
# Generating matrix of gene pair 0 16
# Generating matrix of gene pair 0 17
# Generating matrix of gene pair 0 18
# Generating matrix of gene pair 0 19
# Generating matrix of gene pair 0 20
# Generating matrix of gene pair 0 21
# Generating matrix of gene pair 0 22
# Generating matrix of gene pair 0 23
# Generating matrix of gene pair 0 24
# Generating matrix of gene pair 0 25
# Generating matrix of gene pair 0 26
# Generating matrix of gene pair 0 27
# Generating matrix of gene pair 0 28
# Generating matrix of gene pair 0 29
# Generating matrix of gene pair 0 30
# Generating matrix of gene pair 0 31
# Generating matrix of gene pair 0 32
# Generating matrix of gene pair 0 33
# Generating matrix of gene pair 0 34
# Generating matrix of gene pair 0 35
# Generating matrix of gene pair 0 36
# Generating matrix of gene pair 0 37
# Generating matrix of gene pair 0 38
# Generating matrix of gene pair 0 39
# Generating matrix of gene pair 0 40
# Generating matrix of gene pair 0 41
# Generating matrix of gene pair 0 42
# Generating matrix of gene pair 0 43
# Generating matrix of gene pair 0 44
# Generating matrix of gene pair 0 45
# Generating matrix of gene pair 0 46
# Generating matrix of gene pair 0 47
# Generating matrix of gene pair 0 48
# Generating matrix of gene pair 0 49
# Generating matrix of gene pair 0 50
# Generating matrix of gene pair 0 51
# Generating matrix of gene pair 0 52
# Generating matrix of gene pair 0 53
# Generating matrix of gene pair 0 54
# Generating matrix of gene pair 0 55
# Generating matrix of gene pair 0 56
# Generating matrix of gene pair 0 57
# Generating matrix of gene pair 0 58
# Generating matrix of gene pair 0 59
# Generating matrix of gene pair 0 60
# Generating matrix of gene pair 1 0
# Generating matrix of gene pair 1 1
# Generating matrix of gene pair 1 2
# Generating matrix of gene pair 1 3
# Generating matrix of gene pair 1 4
# Generating matrix of gene pair 1 5
# Generating matrix of gene pair 1 6
# Generating matrix of gene pair 1 7
# Generating matrix of gene pair 1 8
# Generating matrix of gene pair 1 9
# Generating matrix of gene pair 1 10
# Generating matrix of gene pair 1 11
# Generating matrix of gene pair 1 12
# Generating matrix of gene pair 1 13
# Generating matrix of gene pair 1 14
# Generating matrix of gene pair 1 15
# Generating matrix of gene pair 1 16
# Generating matrix of gene pair 1 17
# Generating matrix of gene pair 1 18
# Generating matrix of gene pair 1 19
# Generating matrix of gene pair 1 20
# Generating matrix of gene pair 1 21
# Generating matrix of gene pair 1 22
# Generating matrix of gene pair 1 23
# Generating matrix of gene pair 1 24
# Generating matrix of gene pair 1 25
# Generating matrix of gene pair 1 26
# Generating matrix of gene pair 1 27
# Generating matrix of gene pair 1 28
# Generating matrix of gene pair 1 29
# Generating matrix of gene pair 1 30
# Generating matrix of gene pair 1 31
# Generating matrix of gene pair 1 32
# Generating matrix of gene pair 1 33
# Generating matrix of gene pair 1 34
# Generating matrix of gene pair 1 35
# Generating matrix of gene pair 1 36
# Generating matrix of gene pair 1 37
# Generating matrix of gene pair 1 38
# Generating matrix of gene pair 1 39
# Generating matrix of gene pair 1 40
# Generating matrix of gene pair 1 41
# Generating matrix of gene pair 1 42
# Generating matrix of gene pair 1 43
# Generating matrix of gene pair 1 44
# Generating matrix of gene pair 1 45
# Generating matrix of gene pair 1 46
# Generating matrix of gene pair 1 47
# Generating matrix of gene pair 1 48
# Generating matrix of gene pair 1 49
# Generating matrix of gene pair 1 50
# Generating matrix of gene pair 1 51
# Generating matrix of gene pair 1 52
# Generating matrix of gene pair 1 53
# Generating matrix of gene pair 1 54
# Generating matrix of gene pair 1 55
# Generating matrix of gene pair 1 56
# Generating matrix of gene pair 1 57
# Generating matrix of gene pair 1 58
# Generating matrix of gene pair 1 59
# Generating matrix of gene pair 1 60
# Generating matrix of gene pair 2 0
# Generating matrix of gene pair 2 1
# Generating matrix of gene pair 2 2
# Generating matrix of gene pair 2 3
# Generating matrix of gene pair 2 4
# Generating matrix of gene pair 2 5
# Generating matrix of gene pair 2 6
# Generating matrix of gene pair 2 7
# Generating matrix of gene pair 2 8
# Generating matrix of gene pair 2 9
# Generating matrix of gene pair 2 10
# Generating matrix of gene pair 2 11
# Generating matrix of gene pair 2 12
# Generating matrix of gene pair 2 13
# Generating matrix of gene pair 2 14
# Generating matrix of gene pair 2 15
# Generating matrix of gene pair 2 16
# Generating matrix of gene pair 2 17
# Generating matrix of gene pair 2 18
# Generating matrix of gene pair 2 19
# Generating matrix of gene pair 2 20
# Generating matrix of gene pair 2 21
# Generating matrix of gene pair 2 22
# Generating matrix of gene pair 2 23
# Generating matrix of gene pair 2 24
# Generating matrix of gene pair 2 25
# Generating matrix of gene pair 2 26
# Generating matrix of gene pair 2 27
# Generating matrix of gene pair 2 28
# Generating matrix of gene pair 2 29
# Generating matrix of gene pair 2 30
# Generating matrix of gene pair 2 31
# Generating matrix of gene pair 2 32
# Generating matrix of gene pair 2 33
# Generating matrix of gene pair 2 34
# Generating matrix of gene pair 2 35
# Generating matrix of gene pair 2 36
# Generating matrix of gene pair 2 37
# Generating matrix of gene pair 2 38
# Generating matrix of gene pair 2 39
# Generating matrix of gene pair 2 40
# Generating matrix of gene pair 2 41
# Generating matrix of gene pair 2 42
# Generating matrix of gene pair 2 43
# Generating matrix of gene pair 2 44
# Generating matrix of gene pair 2 45
# Generating matrix of gene pair 2 46
# Generating matrix of gene pair 2 47
# Generating matrix of gene pair 2 48
# Generating matrix of gene pair 2 49
# Generating matrix of gene pair 2 50
# Generating matrix of gene pair 2 51
# Generating matrix of gene pair 2 52
# Generating matrix of gene pair 2 53
# Generating matrix of gene pair 2 54
# Generating matrix of gene pair 2 55
# Generating matrix of gene pair 2 56
# Generating matrix of gene pair 2 57
# Generating matrix of gene pair 2 58
# Generating matrix of gene pair 2 59
# Generating matrix of gene pair 2 60
# Generating matrix of gene pair 3 0
# Generating matrix of gene pair 3 1
# Generating matrix of gene pair 3 2
# Generating matrix of gene pair 3 3
# Generating matrix of gene pair 3 4
# Generating matrix of gene pair 3 5
# Generating matrix of gene pair 3 6
# Generating matrix of gene pair 3 7
# Generating matrix of gene pair 3 8
# Generating matrix of gene pair 3 9
# Generating matrix of gene pair 3 10
# Generating matrix of gene pair 3 11
# Generating matrix of gene pair 3 12
# Generating matrix of gene pair 3 13
# Generating matrix of gene pair 3 14
# Generating matrix of gene pair 3 15
# Generating matrix of gene pair 3 16
# Generating matrix of gene pair 3 17
# Generating matrix of gene pair 3 18
# Generating matrix of gene pair 3 19
# Generating matrix of gene pair 3 20
# Generating matrix of gene pair 3 21
# Generating matrix of gene pair 3 22
# Generating matrix of gene pair 3 23
# Generating matrix of gene pair 3 24
# Generating matrix of gene pair 3 25
# Generating matrix of gene pair 3 26
# Generating matrix of gene pair 3 27
# Generating matrix of gene pair 3 28
# Generating matrix of gene pair 3 29
# Generating matrix of gene pair 3 30
# Generating matrix of gene pair 3 31
# Generating matrix of gene pair 3 32
# Generating matrix of gene pair 3 33
# Generating matrix of gene pair 3 34
# Generating matrix of gene pair 3 35
# Generating matrix of gene pair 3 36
# Generating matrix of gene pair 3 37
# Generating matrix of gene pair 3 38
# Generating matrix of gene pair 3 39
# Generating matrix of gene pair 3 40
# Generating matrix of gene pair 3 41
# Generating matrix of gene pair 3 42
# Generating matrix of gene pair 3 43
# Generating matrix of gene pair 3 44
# Generating matrix of gene pair 3 45
# Generating matrix of gene pair 3 46
# Generating matrix of gene pair 3 47
# Generating matrix of gene pair 3 48
# Generating matrix of gene pair 3 49
# Generating matrix of gene pair 3 50
# Generating matrix of gene pair 3 51
# Generating matrix of gene pair 3 52
# Generating matrix of gene pair 3 53
# Generating matrix of gene pair 3 54
# Generating matrix of gene pair 3 55
# Generating matrix of gene pair 3 56
# Generating matrix of gene pair 3 57
# Generating matrix of gene pair 3 58
# Generating matrix of gene pair 3 59
# Generating matrix of gene pair 3 60
# Generating matrix of gene pair 4 0
# Generating matrix of gene pair 4 1
# Generating matrix of gene pair 4 2
# Generating matrix of gene pair 4 3
# Generating matrix of gene pair 4 4
# Generating matrix of gene pair 4 5
# Generating matrix of gene pair 4 6
# Generating matrix of gene pair 4 7
# Generating matrix of gene pair 4 8
# Generating matrix of gene pair 4 9
# Generating matrix of gene pair 4 10
# Generating matrix of gene pair 4 11
# Generating matrix of gene pair 4 12
# Generating matrix of gene pair 4 13
# Generating matrix of gene pair 4 14
# Generating matrix of gene pair 4 15
# Generating matrix of gene pair 4 16
# Generating matrix of gene pair 4 17
# Generating matrix of gene pair 4 18
# Generating matrix of gene pair 4 19
# Generating matrix of gene pair 4 20
# Generating matrix of gene pair 4 21
# Generating matrix of gene pair 4 22
# Generating matrix of gene pair 4 23
# Generating matrix of gene pair 4 24
# Generating matrix of gene pair 4 25
# Generating matrix of gene pair 4 26
# Generating matrix of gene pair 4 27
# Generating matrix of gene pair 4 28
# Generating matrix of gene pair 4 29
# Generating matrix of gene pair 4 30
# Generating matrix of gene pair 4 31
# Generating matrix of gene pair 4 32
# Generating matrix of gene pair 4 33
# Generating matrix of gene pair 4 34
# Generating matrix of gene pair 4 35
# Generating matrix of gene pair 4 36
# Generating matrix of gene pair 4 37
# Generating matrix of gene pair 4 38
# Generating matrix of gene pair 4 39
# Generating matrix of gene pair 4 40
# Generating matrix of gene pair 4 41
# Generating matrix of gene pair 4 42
# Generating matrix of gene pair 4 43
# Generating matrix of gene pair 4 44
# Generating matrix of gene pair 4 45
# Generating matrix of gene pair 4 46
# Generating matrix of gene pair 4 47
# Generating matrix of gene pair 4 48
# Generating matrix of gene pair 4 49
# Generating matrix of gene pair 4 50
# Generating matrix of gene pair 4 51
# Generating matrix of gene pair 4 52
# Generating matrix of gene pair 4 53
# Generating matrix of gene pair 4 54
# Generating matrix of gene pair 4 55
# Generating matrix of gene pair 4 56
# Generating matrix of gene pair 4 57
# Generating matrix of gene pair 4 58
# Generating matrix of gene pair 4 59
# Generating matrix of gene pair 4 60
# Generating matrix of gene pair 5 0
# Generating matrix of gene pair 5 1
# Generating matrix of gene pair 5 2
# Generating matrix of gene pair 5 3
# Generating matrix of gene pair 5 4
# Generating matrix of gene pair 5 5
# Generating matrix of gene pair 5 6
# Generating matrix of gene pair 5 7
# Generating matrix of gene pair 5 8
# Generating matrix of gene pair 5 9
# Generating matrix of gene pair 5 10
# Generating matrix of gene pair 5 11
# Generating matrix of gene pair 5 12
# Generating matrix of gene pair 5 13
# Generating matrix of gene pair 5 14
# Generating matrix of gene pair 5 15
# Generating matrix of gene pair 5 16
# Generating matrix of gene pair 5 17
# Generating matrix of gene pair 5 18
# Generating matrix of gene pair 5 19
# Generating matrix of gene pair 5 20
# Generating matrix of gene pair 5 21
# Generating matrix of gene pair 5 22
# Generating matrix of gene pair 5 23
# Generating matrix of gene pair 5 24
# Generating matrix of gene pair 5 25
# Generating matrix of gene pair 5 26
# Generating matrix of gene pair 5 27
# Generating matrix of gene pair 5 28
# Generating matrix of gene pair 5 29
# Generating matrix of gene pair 5 30
# Generating matrix of gene pair 5 31
# Generating matrix of gene pair 5 32
# Generating matrix of gene pair 5 33
# Generating matrix of gene pair 5 34
# Generating matrix of gene pair 5 35
# Generating matrix of gene pair 5 36
# Generating matrix of gene pair 5 37
# Generating matrix of gene pair 5 38
# Generating matrix of gene pair 5 39
# Generating matrix of gene pair 5 40
# Generating matrix of gene pair 5 41
# Generating matrix of gene pair 5 42
# Generating matrix of gene pair 5 43
# Generating matrix of gene pair 5 44
# Generating matrix of gene pair 5 45
# Generating matrix of gene pair 5 46
# Generating matrix of gene pair 5 47
# Generating matrix of gene pair 5 48
# Generating matrix of gene pair 5 49
# Generating matrix of gene pair 5 50
# Generating matrix of gene pair 5 51
# Generating matrix of gene pair 5 52
# Generating matrix of gene pair 5 53
# Generating matrix of gene pair 5 54
# Generating matrix of gene pair 5 55
# Generating matrix of gene pair 5 56
# Generating matrix of gene pair 5 57
# Generating matrix of gene pair 5 58
# Generating matrix of gene pair 5 59
# Generating matrix of gene pair 5 60
# Generating matrix of gene pair 6 0
# Generating matrix of gene pair 6 1
# Generating matrix of gene pair 6 2
# Generating matrix of gene pair 6 3
# Generating matrix of gene pair 6 4
# Generating matrix of gene pair 6 5
# Generating matrix of gene pair 6 6
# Generating matrix of gene pair 6 7
# Generating matrix of gene pair 6 8
# Generating matrix of gene pair 6 9
# Generating matrix of gene pair 6 10
# Generating matrix of gene pair 6 11
# Generating matrix of gene pair 6 12
# Generating matrix of gene pair 6 13
# Generating matrix of gene pair 6 14
# Generating matrix of gene pair 6 15
# Generating matrix of gene pair 6 16
# Generating matrix of gene pair 6 17
# Generating matrix of gene pair 6 18
# Generating matrix of gene pair 6 19
# Generating matrix of gene pair 6 20
# Generating matrix of gene pair 6 21
# Generating matrix of gene pair 6 22
# Generating matrix of gene pair 6 23
# Generating matrix of gene pair 6 24
# Generating matrix of gene pair 6 25
# Generating matrix of gene pair 6 26
# Generating matrix of gene pair 6 27
# Generating matrix of gene pair 6 28
# Generating matrix of gene pair 6 29
# Generating matrix of gene pair 6 30
# Generating matrix of gene pair 6 31
# Generating matrix of gene pair 6 32
# Generating matrix of gene pair 6 33
# Generating matrix of gene pair 6 34
# Generating matrix of gene pair 6 35
# Generating matrix of gene pair 6 36
# Generating matrix of gene pair 6 37
# Generating matrix of gene pair 6 38
# Generating matrix of gene pair 6 39
# Generating matrix of gene pair 6 40
# Generating matrix of gene pair 6 41
# Generating matrix of gene pair 6 42
# Generating matrix of gene pair 6 43
# Generating matrix of gene pair 6 44
# Generating matrix of gene pair 6 45
# Generating matrix of gene pair 6 46
# Generating matrix of gene pair 6 47
# Generating matrix of gene pair 6 48
# Generating matrix of gene pair 6 49
# Generating matrix of gene pair 6 50
# Generating matrix of gene pair 6 51
# Generating matrix of gene pair 6 52
# Generating matrix of gene pair 6 53
# Generating matrix of gene pair 6 54
# Generating matrix of gene pair 6 55
# Generating matrix of gene pair 6 56
# Generating matrix of gene pair 6 57
# Generating matrix of gene pair 6 58
# Generating matrix of gene pair 6 59
# Generating matrix of gene pair 6 60
# Generating matrix of gene pair 7 0
# Generating matrix of gene pair 7 1
# Generating matrix of gene pair 7 2
# Generating matrix of gene pair 7 3
# ...
# single_pair ['PITX2', 'NFYB', '0']
# single_pair ['NFYB', 'OTX2', '0']
# single_pair ['MCM4', 'RBP4', '0']
# single_pair ['DDIT3', 'ANAPC7', '0']
# single_pair ['FOS', 'HESX1', '0']
# single_pair ['KLF6', 'CCNB1', '0']
# single_pair ['MCM3', 'MCM7', '1']
# single_pair ['ZNF143', 'AURKA', '0']
# single_pair ['ZNF143', 'RUVBL1', '0']
# single_pair ['FOS', 'OCIAD2', '1']
# single_pair ['PTTG1', 'PCCA', '0']
# single_pair ['ID3', 'ACTL6A', '0']
# single_pair ['RUVBL1', 'VTN', '0']
# single_pair ['ID3', 'AURKA', '0']
# single_pair ['FOS', 'CENPF', '0']
# single_pair ['PTTG1', 'NFYB', '0']
# single_pair ['ID3', 'NEK2', '0']
# single_pair ['TGIF1', 'OCIAD2', '0']
# single_pair ['MCM3', 'FANCB', '0']
# single_pair ['KNTC1', 'ADM', '0']
# single_pair ['MCM7', 'DDIT3', '0']
# single_pair ['FOS', 'CCNB1', '0']
# single_pair ['RUVBL1', 'ACTC1', '0']
# single_pair ['CRABP2', 'CCNB1', '0']
# single_pair ['TGIF1', 'ACADVL', '0']
# single_pair ['KNTC1', 'GRPR', '0']
# single_pair ['KLF6', 'GPC3', '0']
# single_pair ['ZNF143', 'PCNA', '0']
# single_pair ['ZNF143', 'UBE2T', '0']
# single_pair ['ID2', 'RUVBL1', '0']
# single_pair ['PTTG1', 'MTFP1', '0']
# single_pair ['KNTC1', 'TF', '0']
# single_pair ['PTTG1', 'AURKA', '0']
# single_pair ['MCM4', 'BUB1B', '0']
# single_pair ['PTTG1', 'VTN', '0']
# single_pair ['OTX2', 'MRPS27', '0']
# single_pair ['MCM4', 'NEK2', '0']
# single_pair ['NFYB', 'KIF20B', '0']
# single_pair ['PITX2', 'ACTC1', '0']
# single_pair ['TGIF1', 'UQCC1', '0']
# single_pair ['OTX2', 'PRMT5', '0']
# single_pair ['ZNF143', 'ACADVL', '0']
# single_pair ['RUVBL1', 'SCHIP1', '0']
# single_pair ['MCM3', 'PIM2', '0']
# single_pair ['KLF6', 'ATG5', '0']
# single_pair ['DDIT3', 'NIP7', '1']
# single_pair ['ZNF143', 'VTN', '0']
# single_pair ['MCM3', 'APEH', '0']
# single_pair ['OTX2', 'PLK1', '0']
# single_pair ['MCM3', 'DKC1', '0']
# single_pair ['KNTC1', 'UTRN', '0']
# single_pair ['DDIT3', 'CYP3A5', '0']
# single_pair ['PTTG1', 'ACADVL', '0']
# single_pair ['CRABP2', 'ANAPC7', '0']
# single_pair ['KLF6', 'ID3', '0']
# single_pair ['ZNF143', 'GPC3', '0']
# single_pair ['MCM4', 'ZWILCH', '0']
# single_pair ['CRABP2', 'PTTG1', '0']
# single_pair ['TGIF1', 'RBP4', '0']
# single_pair ['KNTC1', 'PHF5A', '0']
# single_pair ['ID2', 'PCCA', '0']
# single_pair ['MCM7', 'GPC3', '0']
# single_pair ['MCM4', 'F3', '0']
# single_pair ['NFYB', 'UQCC1', '0']
# single_pair ['ID2', 'PMAIP1', '0']
# single_pair ['NFYB', 'PRMT5', '0']
# single_pair ['MCM4', 'UQCC1', '0']
# single_pair ['RUVBL1', 'LGALS1', '0']
# single_pair ['NFYB', 'CCL2', '0']
# single_pair ['ID2', 'ANXA3', '0']
# single_pair ['FOS', 'HAUS1', '0']
# single_pair ['ID3', 'CDC20', '0']
# single_pair ['OTX2', 'ACTL6A', '0']
# single_pair ['MCM7', 'CYP3A5', '0']
# single_pair ['NFYB', 'PCNA', '1']
# single_pair ['NFYB', 'DDIT3', '1']
# single_pair ['ID2', 'ATG5', '0']
# single_pair ['OTX2', 'NIP7', '0']
# single_pair ['MCM7', 'SMYD3', '0']
# single_pair ['PTTG1', 'TF', '0']
# single_pair ['CRABP2', 'RUVBL1', '0']
# single_pair ['ID3', 'HESX1', '0']
# single_pair ['OTX2', 'LGALS3', '0']
# single_pair ['ZNF143', 'HESX1', '0']
# single_pair ['PTTG1', 'GRPR', '0']
# single_pair ['KNTC1', 'UQCC1', '0']
# single_pair ['CRABP2', 'ACADVL', '0']
# single_pair ['KLF6', 'ANXA3', '0']
# single_pair ['PITX2', 'CRABP2', '0']
# single_pair ['ZNF143', 'GRPR', '0']
# single_pair ['ZNF143', 'PCCA', '0']
# single_pair ['TGIF1', 'CAPN12', '0']
# single_pair ['ID2', 'CA2', '0']
# single_pair ['PTTG1', 'NEK2', '0']
# single_pair ['RUVBL1', 'TGIF1', '0']
# single_pair ['ZNF143', 'CCBL2', '0']
# single_pair ['MCM4', 'CACYBP', '0']
# single_pair ['ID3', 'KNTC1', '0']
# single_pair ['MCM3', 'RUVBL1', '0']
# single_pair ['MCM7', 'PLK1', '1']
# single_pair ['FOS', 'NIF3L1', '0']
# single_pair ['NFYB', 'CDC20', '0']
# single_pair ['KLF6', 'ZNF143', '0']
# single_pair ['CRABP2', 'ANXA3', '0']
# single_pair ['MCM7', 'SCHIP1', '0']
# single_pair ['PITX2', 'DKC1', '0']
# single_pair ['MCM7', 'KNTC1', '0']
# single_pair ['FOS', 'PCNA', '0']
# single_pair ['OTX2', 'CHEK2', '0']
# single_pair ['FOS', 'CCNH', '0']
# single_pair ['DDIT3', 'ID3', '1']
# single_pair ['FOS', 'ADM', '1']
# single_pair ['NFYB', 'ID3', '0']
# single_pair ['PITX2', 'IQGAP2', '0']
# single_pair ['PITX2', 'MTFP1', '0']
# single_pair ['MCM3', 'WARS', '0']
# single_pair ['OTX2', 'MCM4', '0']
# single_pair ['ZNF143', 'RBP4', '0']
# single_pair ['NFYB', 'TGIF1', '0']
# single_pair ['CRABP2', 'CA2', '0']
# single_pair ['OTX2', 'FOS', '0']
# single_pair ['NFYB', 'MCM7', '0']
# single_pair ['TGIF1', 'PLK1', '0']
# single_pair ['MCM4', 'PHF5A', '0']
# single_pair ['KLF6', 'NIP7', '0']
# single_pair ['KNTC1', 'PRKCE', '0']
# single_pair ['NFYB', 'NEK2', '0']
# single_pair ['PITX2', 'MRPS27', '0']
# single_pair ['ZNF143', 'TM2D2', '0']
# single_pair ['KLF6', 'AURKA', '0']
# single_pair ['MCM4', 'PCCA', '0']
# single_pair ['ID3', 'KLF6', '0']
# single_pair ['ZNF143', 'ACTC1', '0']
# single_pair ['RUVBL1', 'GSN', '0']
# single_pair ['FOS', 'DDIT3', '1']
# single_pair ['ZNF143', 'TNFRSF12A', '0']
# single_pair ['OTX2', 'HESX1', '1']
# single_pair ['TGIF1', 'NFYB', '0']
# single_pair ['CRABP2', 'CAMK2D', '0']
# single_pair ['PITX2', 'CENPF', '0']
# single_pair ['ID2', 'NIP7', '0']
# single_pair ['KNTC1', 'GSN', '0']
# single_pair ['MCM4', 'DPYSL2', '0']
# single_pair ['KNTC1', 'CAPN12', '0']
# single_pair ['MCM4', 'RUVBL1', '0']
# single_pair ['PITX2', 'SMYD3', '0']
# single_pair ['DDIT3', 'CRABP2', '0']
# single_pair ['FOS', 'ACTL6A', '0']
# single_pair ['ID3', 'PCNA', '0']
# single_pair ['TGIF1', 'PIM2', '0']
# single_pair ['ID2', 'EFTUD2', '0']
# single_pair ['MCM3', 'EFTUD2', '0']
# single_pair ['MCM3', 'KNTC1', '0']
# single_pair ['MCM4', 'ANAPC7', '0']
# single_pair ['ID3', 'APEH', '0']
# single_pair ['DDIT3', 'GRPR', '0']
# single_pair ['ID2', 'ZNF143', '0']
# single_pair ['KLF6', 'MRPS27', '0']
# single_pair ['DDIT3', 'DPCD', '0']
# single_pair ['FOS', 'PITX2', '0']
# single_pair ['PTTG1', 'OCIAD2', '0']
# single_pair ['OTX2', 'TNNI3', '0']
# single_pair ['MCM3', 'VTN', '0']
# single_pair ['ZNF143', 'DKC1', '0']
# single_pair ['PTTG1', 'PMAIP1', '0']
# single_pair ['MCM3', 'SCHIP1', '0']
# single_pair ['DDIT3', 'OCIAD2', '0']
# single_pair ['NFYB', 'ASNS', '0']
# single_pair ['FOS', 'PRKCE', '1']
# single_pair ['CRABP2', 'MT2A', '0']
# single_pair ['OTX2', 'FANCB', '0']
# single_pair ['PITX2', 'ADM', '0']
# single_pair ['MCM3', 'PMAIP1', '0']
# single_pair ['DDIT3', 'CDC20', '0']
# single_pair ['ID3', 'GPC3', '0']
# single_pair ['MCM4', 'TGIF1', '0']
# single_pair ['FOS', 'PCCA', '1']
# single_pair ['MCM7', 'CCBL2', '0']
# single_pair ['OTX2', 'ACADVL', '0']
# single_pair ['ZNF143', 'PRMT5', '0']
# single_pair ['MCM3', 'PHF5A', '0']
# single_pair ['PITX2', 'PLK1', '0']
# single_pair ['TGIF1', 'CCBL2', '0']
# single_pair ['OTX2', 'ACTC1', '0']
# single_pair ['MCM4', 'LGALS1', '0']
# single_pair ['DDIT3', 'CCNH', '0']
# single_pair ['OTX2', 'UBE2T', '0']
# single_pair ['MCM7', 'NIP7', '0']
# single_pair ['NFYB', 'PLCD1', '0']
# single_pair ['PTTG1', 'ATG5', '0']
# single_pair ['ZNF143', 'OTX2', '0']
# single_pair ['ID2', 'CCBL2', '0']
# single_pair ['MCM4', 'CCNH', '0']
# single_pair ['KNTC1', 'KLF6', '0']
# single_pair ['PITX2', 'NEK2', '0']
# single_pair ['DDIT3', 'MT2A', '0']
# single_pair ['DDIT3', 'CCL2', '0']
# single_pair ['TGIF1', 'ZWILCH', '0']
# single_pair ['CRABP2', 'CYP3A5', '0']
# single_pair ['CRABP2', 'NIF3L1', '0']
# single_pair ['ID3', 'OTX2', '0']
# single_pair ['PTTG1', 'MRPS27', '0']
# single_pair ['ID3', 'SCHIP1', '0']
# single_pair ['PTTG1', 'CCS', '0']
# single_pair ['ID3', 'TGIF1', '0']
# single_pair ['PITX2', 'MCM4', '0']
# single_pair ['KNTC1', 'ID3', '0']
# single_pair ['PITX2', 'DPCD', '0']
# single_pair ['KLF6', 'TGIF1', '0']
# single_pair ['MCM3', 'NIF3L1', '0']
# single_pair ['PITX2', 'TF', '0']
# single_pair ['MCM4', 'TNNI3', '0']
# single_pair ['FOS', 'NIP7', '0']
# single_pair ['TGIF1', 'ACTC1', '1']
# single_pair ['CRABP2', 'ICA1', '0']
# single_pair ['FOS', 'PTTG1', '0']
# single_pair ['TGIF1', 'NIF3L1', '0']
# single_pair ['OTX2', 'IQGAP2', '0']
# single_pair ['PTTG1', 'ACTL6A', '0']
# single_pair ['KLF6', 'CYP3A5', '0']
# single_pair ['PTTG1', 'CAPN12', '0']
# single_pair ['MCM3', 'LGALS1', '0']
# single_pair ['ID2', 'ACTC1', '0']
# single_pair ['CRABP2', 'MCM4', '0']
# single_pair ['RUVBL1', 'APEH', '0']
# single_pair ['ZNF143', 'SCHIP1', '0']
# single_pair ['FOS', 'PLK1', '0']
# single_pair ['PTTG1', 'SMYD3', '0']
# single_pair ['CRABP2', 'WARS', '0']
# single_pair ['ID3', 'MCM3', '0']
# single_pair ['FOS', 'TPD52L1', '1']
# single_pair ['OTX2', 'TM2D2', '0']
# All genes:24
# TFs:9
# len(single_pair) 3
# Generating matrix of gene pair 0 0
# Generating matrix of gene pair 0 1
# Generating matrix of gene pair 0 2
# Generating matrix of gene pair 0 3
# Generating matrix of gene pair 0 4
# Generating matrix of gene pair 0 5
# Generating matrix of gene pair 0 6
# Generating matrix of gene pair 0 7
# Generating matrix of gene pair 0 8
# Generating matrix of gene pair 0 9
# Generating matrix of gene pair 0 10
# Generating matrix of gene pair 0 11
# Generating matrix of gene pair 0 12
# Generating matrix of gene pair 0 13
# Generating matrix of gene pair 0 14
# Generating matrix of gene pair 0 15
# Generating matrix of gene pair 0 16
# Generating matrix of gene pair 0 17
# Generating matrix of gene pair 0 18
# Generating matrix of gene pair 0 19
# Generating matrix of gene pair 0 20
# Generating matrix of gene pair 0 21
# Generating matrix of gene pair 0 22
# Generating matrix of gene pair 0 23
# Generating matrix of gene pair 1 0
# Generating matrix of gene pair 1 1
# Generating matrix of gene pair 1 2
# Generating matrix of gene pair 1 3
# Generating matrix of gene pair 1 4
# Generating matrix of gene pair 1 5
# Generating matrix of gene pair 1 6
# Generating matrix of gene pair 1 7
# Generating matrix of gene pair 1 8
# Generating matrix of gene pair 1 9
# Generating matrix of gene pair 1 10
# Generating matrix of gene pair 1 11
# Generating matrix of gene pair 1 12
# Generating matrix of gene pair 1 13
# Generating matrix of gene pair 1 14
# Generating matrix of gene pair 1 15
# Generating matrix of gene pair 1 16
# Generating matrix of gene pair 1 17
# Generating matrix of gene pair 1 18
# Generating matrix of gene pair 1 19
# Generating matrix of gene pair 1 20
# Generating matrix of gene pair 1 21
# Generating matrix of gene pair 1 22
# Generating matrix of gene pair 1 23
# Generating matrix of gene pair 2 0
# Generating matrix of gene pair 2 1
# Generating matrix of gene pair 2 2
# Generating matrix of gene pair 2 3
# Generating matrix of gene pair 2 4
# Generating matrix of gene pair 2 5
# Generating matrix of gene pair 2 6
# Generating matrix of gene pair 2 7
# Generating matrix of gene pair 2 8
# Generating matrix of gene pair 2 9
# Generating matrix of gene pair 2 10
# Generating matrix of gene pair 2 11
# Generating matrix of gene pair 2 12
# Generating matrix of gene pair 2 13
# Generating matrix of gene pair 2 14
# Generating matrix of gene pair 2 15
# Generating matrix of gene pair 2 16
# Generating matrix of gene pair 2 17
# Generating matrix of gene pair 2 18
# Generating matrix of gene pair 2 19
# Generating matrix of gene pair 2 20
# Generating matrix of gene pair 2 21
# Generating matrix of gene pair 2 22
# Generating matrix of gene pair 2 23
# Generating matrix of gene pair 3 0
# Generating matrix of gene pair 3 1
# Generating matrix of gene pair 3 2
# Generating matrix of gene pair 3 3
# Generating matrix of gene pair 3 4
# Generating matrix of gene pair 3 5
# Generating matrix of gene pair 3 6
# Generating matrix of gene pair 3 7
# Generating matrix of gene pair 3 8
# Generating matrix of gene pair 3 9
# Generating matrix of gene pair 3 10
# Generating matrix of gene pair 3 11
# Generating matrix of gene pair 3 12
# Generating matrix of gene pair 3 13
# Generating matrix of gene pair 3 14
# Generating matrix of gene pair 3 15
# Generating matrix of gene pair 3 16
# Generating matrix of gene pair 3 17
# Generating matrix of gene pair 3 18
# Generating matrix of gene pair 3 19
# Generating matrix of gene pair 3 20
# Generating matrix of gene pair 3 21
# Generating matrix of gene pair 3 22
# Generating matrix of gene pair 3 23
# Generating matrix of gene pair 4 0
# Generating matrix of gene pair 4 1
# Generating matrix of gene pair 4 2
# Generating matrix of gene pair 4 3
# Generating matrix of gene pair 4 4
# Generating matrix of gene pair 4 5
# Generating matrix of gene pair 4 6
# Generating matrix of gene pair 4 7
# Generating matrix of gene pair 4 8
# Generating matrix of gene pair 4 9
# Generating matrix of gene pair 4 10
# Generating matrix of gene pair 4 11
# Generating matrix of gene pair 4 12
# Generating matrix of gene pair 4 13
# Generating matrix of gene pair 4 14
# Generating matrix of gene pair 4 15
# Generating matrix of gene pair 4 16
# Generating matrix of gene pair 4 17
# Generating matrix of gene pair 4 18
# Generating matrix of gene pair 4 19
# Generating matrix of gene pair 4 20
# Generating matrix of gene pair 4 21
# Generating matrix of gene pair 4 22
# Generating matrix of gene pair 4 23
# Generating matrix of gene pair 5 0
# Generating matrix of gene pair 5 1
# Generating matrix of gene pair 5 2
# Generating matrix of gene pair 5 3
# Generating matrix of gene pair 5 4
# Generating matrix of gene pair 5 5
# Generating matrix of gene pair 5 6
# Generating matrix of gene pair 5 7
# Generating matrix of gene pair 5 8
# Generating matrix of gene pair 5 9
# Generating matrix of gene pair 5 10
# Generating matrix of gene pair 5 11
# Generating matrix of gene pair 5 12
# Generating matrix of gene pair 5 13
# Generating matrix of gene pair 5 14
# Generating matrix of gene pair 5 15
# Generating matrix of gene pair 5 16
# Generating matrix of gene pair 5 17
# Generating matrix of gene pair 5 18
# Generating matrix of gene pair 5 19
# Generating matrix of gene pair 5 20
# Generating matrix of gene pair 5 21
# Generating matrix of gene pair 5 22
# Generating matrix of gene pair 5 23
# Generating matrix of gene pair 6 0
# Generating matrix of gene pair 6 1
# Generating matrix of gene pair 6 2
# Generating matrix of gene pair 6 3
# Generating matrix of gene pair 6 4
# Generating matrix of gene pair 6 5
# Generating matrix of gene pair 6 6
# Generating matrix of gene pair 6 7
# Generating matrix of gene pair 6 8
# Generating matrix of gene pair 6 9
# Generating matrix of gene pair 6 10
# Generating matrix of gene pair 6 11
# Generating matrix of gene pair 6 12
# Generating matrix of gene pair 6 13
# Generating matrix of gene pair 6 14
# Generating matrix of gene pair 6 15
# Generating matrix of gene pair 6 16
# Generating matrix of gene pair 6 17
# Generating matrix of gene pair 6 18
# Generating matrix of gene pair 6 19
# Generating matrix of gene pair 6 20
# Generating matrix of gene pair 6 21
# Generating matrix of gene pair 6 22
# Generating matrix of gene pair 6 23
# Generating matrix of gene pair 7 0
# Generating matrix of gene pair 7 1
# Generating matrix of gene pair 7 2
# Generating matrix of gene pair 7 3
# Generating matrix of gene pair 7 4
# Generating matrix of gene pair 7 5
# Generating matrix of gene pair 7 6
# Generating matrix of gene pair 7 7
# Generating matrix of gene pair 7 8
# Generating matrix of gene pair 7 9
# Generating matrix of gene pair 7 10
# Generating matrix of gene pair 7 11
# Generating matrix of gene pair 7 12
# Generating matrix of gene pair 7 13
# Generating matrix of gene pair 7 14
# Generating matrix of gene pair 7 15
# Generating matrix of gene pair 7 16
# Generating matrix of gene pair 7 17
# Generating matrix of gene pair 7 18
# Generating matrix of gene pair 7 19
# Generating matrix of gene pair 7 20
# Generating matrix of gene pair 7 21
# Generating matrix of gene pair 7 22
# Generating matrix of gene pair 7 23
# Generating matrix of gene pair 8 0
# Generating matrix of gene pair 8 1
# Generating matrix of gene pair 8 2
# Generating matrix of gene pair 8 3
# Generating matrix of gene pair 8 4
# Generating matrix of gene pair 8 5
# Generating matrix of gene pair 8 6
# Generating matrix of gene pair 8 7
# Generating matrix of gene pair 8 8
# Generating matrix of gene pair 8 9
# Generating matrix of gene pair 8 10
# Generating matrix of gene pair 8 11
# Generating matrix of gene pair 8 12
# Generating matrix of gene pair 8 13
# Generating matrix of gene pair 8 14
# Generating matrix of gene pair 8 15
# Generating matrix of gene pair 8 16
# Generating matrix of gene pair 8 17
# Generating matrix of gene pair 8 18
# Generating matrix of gene pair 8 19
# Generating matrix of gene pair 8 20
# Generating matrix of gene pair 8 21
# Generating matrix of gene pair 8 22
# Generating matrix of gene pair 8 23
# PCC matrix generation finish.
# Positive edges:21
# Negative edges:195
# Density=0.09722222222222222

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import torch
import torch.nn.functional as F
import torch.nn as nn
import warnings
warnings.filterwarnings('ignore')
from sklearn import metrics
import os
import csv
import math
from torch.utils.data import (DataLoader)
torch.set_default_tensor_type(torch.DoubleTensor)

def numpy2loader(X, y, batch_size):
    X_set = torch.from_numpy(X)
    X_loader = DataLoader(X_set, batch_size=batch_size)
    y_set = torch.from_numpy(y)
    y_loader = DataLoader(y_set, batch_size=batch_size)

    return X_loader, y_loader

def loaderToList(data_loader):
    length = len(data_loader)
    data = []
    for i in data_loader:
        data.append(i)
    return data

class PositionalEncoding(nn.Module):

    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

class STGRNS(nn.Module):
    def __init__(self, input_dim, nhead=2, d_model=80, num_classes=2, dropout=0.1):
        super().__init__()
        self.prenet = nn.Linear(input_dim, d_model)
        self.positionalEncoding = PositionalEncoding(d_model=d_model, dropout=dropout)
        self.encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model, dim_feedforward=256, nhead=2, dropout=dropout
        )

        self.pred_layer = nn.Sequential(
            nn.Linear(d_model, d_model),
            nn.ReLU(),
            nn.Linear(d_model, num_classes),
        )

    def forward(self, window_size):
        out = window_size.permute(1, 0, 2)
        out = self.positionalEncoding(out)
        out = self.encoder_layer(out)
        out = out.transpose(0, 1)
        stats = out.mean(dim=1)
        out = self.pred_layer(stats)
        return out



def STGRNSForGRNSRconstruction(batch_sizes, epochs,known_data_path,unknown_data_path,num_threads):
    data_path = known_data_path
    d_models = 200
    torch.set_num_threads(num_threads) #set num_threads
    batch_size = batch_sizes
    log_dir = "log/"
    if (not os.path.isdir(log_dir)):
        os.makedirs(log_dir)

    x_train = np.load(data_path + 'matrix.npy')
    y_train = np.load(data_path + 'label.npy')

    X_trainloader, y_trainloader = numpy2loader(x_train, y_train, batch_size)

    X_trainList = loaderToList(X_trainloader)
    y_trainList = loaderToList(y_trainloader)

    model = STGRNS(input_dim=200, nhead=2, d_model=d_models, num_classes=2)

    criterion = nn.CrossEntropyLoss()

    optimizer = torch.optim.Adam(model.parameters(), lr=0.0003, weight_decay=1e-5)

    n_epochs = epochs
    acc_record = {'train': [], 'dev': []}
    loss_record = {'train': [], 'dev': []}
    model.train()
    for epoch in range(n_epochs):
        train_loss = []
        for j in range(0, len(X_trainList)):
            data = X_trainList[j]
            labels = y_trainList[j]
            logits = model(data)
            labels = torch.tensor(labels, dtype=torch.long)
            loss = criterion(logits, labels)
            optimizer.zero_grad()
            loss.backward()
            grad_norm = nn.utils.clip_grad_norm_(model.parameters(), max_norm=10)
            optimizer.step()
            acc = (logits.argmax(dim=-1) == labels).float().mean()
            train_loss.append(loss.item())
        train_loss = sum(train_loss) / len(train_loss)
        loss_record['train'].append(train_loss)

        print(f"[ Train | {epoch + 1:03d}/{n_epochs:03d} ] loss = {train_loss:.5f}")

    ###predict-----------------------------------------------
    y_predict = []
    data_path = unknown_data_path
    x_test = np.load(data_path + 'matrix.npy')
    y_test = np.load(data_path + 'label.npy')

    X_testloader, y_testloader = numpy2loader(x_test, y_test, batch_size)

    X_testList = loaderToList(X_testloader)
    y_testList = loaderToList(y_testloader)

    model.eval()
    predictions = []
    for k in range(0, len(X_testList)):
        data = X_testList[k]
        with torch.no_grad():
            logits = model(data)
        predt = F.softmax(logits)
        temps = predt.cpu().numpy().tolist()
        for i in temps:
            t = i[1]
            y_predict.append(t)

    # print("y_predict", y_predict)
    fpr, tpr, thresholds = metrics.roc_curve(y_test, y_predict, pos_label=1)
    auc = metrics.auc(fpr, tpr)

    precision, recall, thresholds_PR = metrics.precision_recall_curve(y_test, y_predict)
    AUPR = metrics.auc(recall, precision)
    y_predict2 = []
    for pre in y_predict:
        if(pre >0.001):
            y_predict2.append(1)
        else:
            y_predict2.append(0)
    acc = metrics.accuracy_score(y_test, y_predict2)
    bacc = metrics.balanced_accuracy_score(y_test, y_predict2)
    f1 = metrics.f1_score(y_test, y_predict2)

    ##storing the predicted data
    np.save(log_dir + 'y_test.npy', y_test)
    np.save(log_dir + 'y_predict.npy', y_predict)
    
     ##storing the predicted network
    np.save(log_dir + 'y_predict2.npy', y_predict2)


##the data path of known data
data_path = 'exampleData/input/known/'

##the data path of unknown data
unknown_data_path = 'exampleData/input/unknow/'
num_threads = 1
##training model and then predicting unknown network
STGRNSForGRNSRconstruction(32,200,data_path,unknown_data_path,num_threads)
# Out:
# [ Train | 001/200 ] loss = 0.30389
# [ Train | 002/200 ] loss = 0.30676
# [ Train | 003/200 ] loss = 0.22456
# [ Train | 004/200 ] loss = 0.20945
# [ Train | 005/200 ] loss = 0.19427
# [ Train | 006/200 ] loss = 0.17986
# [ Train | 007/200 ] loss = 0.17240
# [ Train | 008/200 ] loss = 0.17632
# [ Train | 009/200 ] loss = 0.17243
# [ Train | 010/200 ] loss = 0.16354
# [ Train | 011/200 ] loss = 0.14289
# [ Train | 012/200 ] loss = 0.13024
# [ Train | 013/200 ] loss = 0.11794
# [ Train | 014/200 ] loss = 0.12167
# [ Train | 015/200 ] loss = 0.11863
# [ Train | 016/200 ] loss = 0.11246
# [ Train | 017/200 ] loss = 0.12808
# [ Train | 018/200 ] loss = 0.11943
# [ Train | 019/200 ] loss = 0.12246
# [ Train | 020/200 ] loss = 0.08324
# [ Train | 021/200 ] loss = 0.06383
# [ Train | 022/200 ] loss = 0.05276
# [ Train | 023/200 ] loss = 0.05312
# [ Train | 024/200 ] loss = 0.04718
# [ Train | 025/200 ] loss = 0.05625
# [ Train | 026/200 ] loss = 0.05256
# [ Train | 027/200 ] loss = 0.05229
# [ Train | 028/200 ] loss = 0.05013
# [ Train | 029/200 ] loss = 0.05511
# [ Train | 030/200 ] loss = 0.09490
# [ Train | 031/200 ] loss = 0.06567
# [ Train | 032/200 ] loss = 0.03432
# [ Train | 033/200 ] loss = 0.03087
# [ Train | 034/200 ] loss = 0.02003
# [ Train | 035/200 ] loss = 0.01754
# [ Train | 036/200 ] loss = 0.01366
# [ Train | 037/200 ] loss = 0.01509
# [ Train | 038/200 ] loss = 0.02552
# [ Train | 039/200 ] loss = 0.03160
# [ Train | 040/200 ] loss = 0.02046
# [ Train | 041/200 ] loss = 0.01240
# [ Train | 042/200 ] loss = 0.01619
# [ Train | 043/200 ] loss = 0.01431
# [ Train | 044/200 ] loss = 0.02410
# [ Train | 045/200 ] loss = 0.01670
# [ Train | 046/200 ] loss = 0.01280
# [ Train | 047/200 ] loss = 0.01672
# [ Train | 048/200 ] loss = 0.02041
# [ Train | 049/200 ] loss = 0.04024
# [ Train | 050/200 ] loss = 0.13848
# [ Train | 051/200 ] loss = 0.15826
# [ Train | 052/200 ] loss = 0.04413
# [ Train | 053/200 ] loss = 0.02419
# [ Train | 054/200 ] loss = 0.01070
# [ Train | 055/200 ] loss = 0.00965
# [ Train | 056/200 ] loss = 0.00878
# [ Train | 057/200 ] loss = 0.01185
# [ Train | 058/200 ] loss = 0.02089
# [ Train | 059/200 ] loss = 0.03817
# [ Train | 060/200 ] loss = 0.02260
# [ Train | 061/200 ] loss = 0.01051
# [ Train | 062/200 ] loss = 0.01012
# [ Train | 063/200 ] loss = 0.00898
# [ Train | 064/200 ] loss = 0.00728
# [ Train | 065/200 ] loss = 0.01139
# [ Train | 066/200 ] loss = 0.01538
# [ Train | 067/200 ] loss = 0.01124
# [ Train | 068/200 ] loss = 0.00491
# [ Train | 069/200 ] loss = 0.00371
# [ Train | 070/200 ] loss = 0.00316
# [ Train | 071/200 ] loss = 0.00269
# [ Train | 072/200 ] loss = 0.00237
# [ Train | 073/200 ] loss = 0.00478
# [ Train | 074/200 ] loss = 0.00707
# [ Train | 075/200 ] loss = 0.00690
# [ Train | 076/200 ] loss = 0.00275
# [ Train | 077/200 ] loss = 0.00295
# [ Train | 078/200 ] loss = 0.00251
# [ Train | 079/200 ] loss = 0.00161
# [ Train | 080/200 ] loss = 0.00311
# [ Train | 081/200 ] loss = 0.00805
# [ Train | 082/200 ] loss = 0.00581
# [ Train | 083/200 ] loss = 0.01100
# [ Train | 084/200 ] loss = 0.01883
# [ Train | 085/200 ] loss = 0.01659
# [ Train | 086/200 ] loss = 0.03850
# [ Train | 087/200 ] loss = 0.01703
# [ Train | 088/200 ] loss = 0.00743
# [ Train | 089/200 ] loss = 0.01061
# [ Train | 090/200 ] loss = 0.01403
# [ Train | 091/200 ] loss = 0.00915
# [ Train | 092/200 ] loss = 0.01066
# [ Train | 093/200 ] loss = 0.02603
# [ Train | 094/200 ] loss = 0.01245
# [ Train | 095/200 ] loss = 0.00996
# [ Train | 096/200 ] loss = 0.00232
# [ Train | 097/200 ] loss = 0.00233
# [ Train | 098/200 ] loss = 0.00378
# [ Train | 099/200 ] loss = 0.00310
# [ Train | 100/200 ] loss = 0.00287
# [ Train | 101/200 ] loss = 0.00152
# [ Train | 102/200 ] loss = 0.00238
# [ Train | 103/200 ] loss = 0.00181
# [ Train | 104/200 ] loss = 0.00256
# [ Train | 105/200 ] loss = 0.00161
# [ Train | 106/200 ] loss = 0.00566
# [ Train | 107/200 ] loss = 0.01195
# [ Train | 108/200 ] loss = 0.02138
# [ Train | 109/200 ] loss = 0.04800
# [ Train | 110/200 ] loss = 0.05032
# [ Train | 111/200 ] loss = 0.02673
# [ Train | 112/200 ] loss = 0.01416
# [ Train | 113/200 ] loss = 0.00754
# [ Train | 114/200 ] loss = 0.00402
# [ Train | 115/200 ] loss = 0.00511
# [ Train | 116/200 ] loss = 0.00874
# [ Train | 117/200 ] loss = 0.00605
# [ Train | 118/200 ] loss = 0.00493
# [ Train | 119/200 ] loss = 0.00300
# [ Train | 120/200 ] loss = 0.00482
# [ Train | 121/200 ] loss = 0.00109
# [ Train | 122/200 ] loss = 0.00122
# [ Train | 123/200 ] loss = 0.00155
# [ Train | 124/200 ] loss = 0.00142
# [ Train | 125/200 ] loss = 0.00147
# [ Train | 126/200 ] loss = 0.00653
# [ Train | 127/200 ] loss = 0.00576
# [ Train | 128/200 ] loss = 0.01101
# [ Train | 129/200 ] loss = 0.01536
# [ Train | 130/200 ] loss = 0.02300
# [ Train | 131/200 ] loss = 0.00467
# [ Train | 132/200 ] loss = 0.00873
# [ Train | 133/200 ] loss = 0.00825
# [ Train | 134/200 ] loss = 0.00484
# [ Train | 135/200 ] loss = 0.00515
# [ Train | 136/200 ] loss = 0.00074
# [ Train | 137/200 ] loss = 0.00139
# [ Train | 138/200 ] loss = 0.00100
# [ Train | 139/200 ] loss = 0.00049
# [ Train | 140/200 ] loss = 0.00486
# [ Train | 141/200 ] loss = 0.00388
# [ Train | 142/200 ] loss = 0.00392
# [ Train | 143/200 ] loss = 0.00486
# [ Train | 144/200 ] loss = 0.00102
# [ Train | 145/200 ] loss = 0.00112
# [ Train | 146/200 ] loss = 0.00261
# [ Train | 147/200 ] loss = 0.00057
# [ Train | 148/200 ] loss = 0.00091
# [ Train | 149/200 ] loss = 0.00130
# [ Train | 150/200 ] loss = 0.00083
# [ Train | 151/200 ] loss = 0.00372
# [ Train | 152/200 ] loss = 0.00517
# [ Train | 153/200 ] loss = 0.00576
# [ Train | 154/200 ] loss = 0.02408
# [ Train | 155/200 ] loss = 0.00548
# [ Train | 156/200 ] loss = 0.00340
# [ Train | 157/200 ] loss = 0.01391
# [ Train | 158/200 ] loss = 0.13558
# [ Train | 159/200 ] loss = 0.20124
# [ Train | 160/200 ] loss = 0.03237
# [ Train | 161/200 ] loss = 0.03212
# [ Train | 162/200 ] loss = 0.04543
# [ Train | 163/200 ] loss = 0.05724
# [ Train | 164/200 ] loss = 0.01918
# [ Train | 165/200 ] loss = 0.00855
# [ Train | 166/200 ] loss = 0.00716
# [ Train | 167/200 ] loss = 0.00566
# [ Train | 168/200 ] loss = 0.00333
# [ Train | 169/200 ] loss = 0.00258
# [ Train | 170/200 ] loss = 0.01568
# [ Train | 171/200 ] loss = 0.01755
# [ Train | 172/200 ] loss = 0.00618
# [ Train | 173/200 ] loss = 0.00681
# [ Train | 174/200 ] loss = 0.00399
# [ Train | 175/200 ] loss = 0.00600
# [ Train | 176/200 ] loss = 0.02172
# [ Train | 177/200 ] loss = 0.01975
# [ Train | 178/200 ] loss = 0.05320
# [ Train | 179/200 ] loss = 0.04677
# [ Train | 180/200 ] loss = 0.02800
# [ Train | 181/200 ] loss = 0.00662
# [ Train | 182/200 ] loss = 0.00556
# [ Train | 183/200 ] loss = 0.00266
# [ Train | 184/200 ] loss = 0.00320
# [ Train | 185/200 ] loss = 0.00394
# [ Train | 186/200 ] loss = 0.00218
# [ Train | 187/200 ] loss = 0.00229
# [ Train | 188/200 ] loss = 0.00204
# [ Train | 189/200 ] loss = 0.00101
# [ Train | 190/200 ] loss = 0.00163
# [ Train | 191/200 ] loss = 0.00151
# [ Train | 192/200 ] loss = 0.00143
# [ Train | 193/200 ] loss = 0.00223
# [ Train | 194/200 ] loss = 0.00114
# [ Train | 195/200 ] loss = 0.00067
# [ Train | 196/200 ] loss = 0.00140
# [ Train | 197/200 ] loss = 0.00079
# [ Train | 198/200 ] loss = 0.00372
# [ Train | 199/200 ] loss = 0.00431
# [ Train | 200/200 ] loss = 0.00605
# acc: 0.7361111111111112
